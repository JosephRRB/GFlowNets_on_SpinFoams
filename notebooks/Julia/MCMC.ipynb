# %% [markdown]
# # Markov Chain Monte Carlo (MCMC)

# %% [markdown]
# Let's consider a quantity $O$ which can be computed as:
#
# $$
# O = \sum\limits_{x \in \chi} o \left( x \right) \tilde{f} \left( x \right) \ ,
# $$
#
# where $x$ is a (possibly multidimensional) discrete variable on a state space $\chi$ which must be summed over, while $\tilde{f}$ is a probability density function on $\chi$, so that $\sum\limits_{x \in \chi} \tilde{f} \left( x \right) = 1$. From now on, we define $\tilde{f}$ as the $\textbf{target}$ distribution and we omit the state space label $\chi$. Since the target distribution is normalized, we can write:
#
# $$
# \tilde{f} \left( x \right) \equiv \frac{f \left( x \right)}{\sum\limits_{x} f \left( x \right)} \ ,
# $$
#
# from which:
#
# $$
# O = \frac{ \sum\limits_{x} f \left( x \right) o \left( x \right) }{\sum\limits_{x} f \left( x \right)} \ .
# $$
#
# If the target distribution is computable up to a multiplying constant, the $\textbf{Metropolis–Hastings algorithm}$ allows to construct on state space $\chi$ an ergodic Markov chain with length $N_{MC}$: $x_{1} , \ x_{2} , \ x_{3} \dots , x_{n} \ \dots , x_{N_{MC}}$ such that $x_{n}$ is converging (in distribution) to $\tilde{f}$, exploring the space $\chi$ progressively. If we define:
#
# $$
# O_{N_{MC}} = \frac{1}{N_{MC}} \sum\limits_{i = 1}^{N_{MC}} o \left(x_i \right) \ ,
# $$
#
# then, since the chain can be considered as a statistical sample, the law of large numbers ensures that:
#
# $$
# \lim_{N_{MC} \to \infty} O_{N_{MC}}  = O \ ,
# $$
#
# which allows us to write:
#
# $$
# O_{N_{MC}} \approx O \hspace{3mm} \textrm{for $N_{MC} \gg 1$} \ .
# $$
#
# Namely, we end up with an estimate of the original sum. Since the simulation is Markovian and the chain itself can be considered as a statistical sample, the latter usually depends on the starting value. The initial steps are tipically removed as $\textbf{burn-in}$, when the chain is still in the so-called $\textbf{thermalization}$ phase.
#
# In order to transit from the value $x_{n}$ of the chain to the value $x_{n + 1}$, we require a $\textbf{proposal distribution}$ $q$ defined on space $\chi$. If $q$ is positive everywhere, then the Metropolis-Hastings algorithm preserves $\tilde{f}$ as the stationary distribution to which the chain is progressively converging.
#
# In the $\textbf{random walk Metropolis-Hastings}$, the proposal distribution consists in a local exploration of the neighborhood of the current value $x_n$ of the
# Markov chain. That is, the proposed value $y_n$ is simulated as:
#
# $$
# y_n = x_n + \epsilon_n \ ,
# $$
#
# where $\epsilon_n$ is a random perturbation with distribution $g$. As proposal distribution $g$, we focus on a discrete truncated normal distribution centered on $x_n$. A few relevant definitions are discussed next.
#
# Finally, since $x_n$ depends on the previous element along the Markov chain, this induces a non-zero correlation between $x_n$ and $x_{n+d}$. The correlation between $x_n$ and $x_{n+d}$ is defined as the $\textbf{autocorrelation}$ at lag $d$. For a Markov chain that converges to a stationary distribution, the autocorrelation should indeed decrease as the lag increases. The definition of the autocorrelation function between the chain elements $x_n$ and $x_{n+d}$ is defined as the expected value $\mathbb{E} \left(x_n x_{n+d} \right) $.
#
# ### Truncated normal distribution
#
# The probability density function of a normal distribution with mean $0$ and standard deviation $\sigma$ is defined as:
#
# $$
# \mathcal{N}(x, \sigma) = \frac{1}{\sigma \sqrt{2 \pi}}e^{-\frac{x^2}{2 \sigma^2}} \ ,
# $$
#
# where $x \in \mathbb{R}$. The probability density function of a normal distribution with mean $\mu$ is simply given by $\mathcal{N}(x - \mu, \sigma)$ .
#
#
# In the discrete (integer) case, we can define the probability density function of a normal distribution with mean $0$ and standard deviation $\sigma$ as:
#
# $$
# \mathcal{N}_{d}(n, \sigma) = \Phi ( n + 0.5, \sigma ) - \Phi (n - 0.5, \sigma ) \ ,
# $$
#
# where $n \in \mathbb{N}$ and $\Phi ( x, \sigma ) $ is the cumulative distribution function of a normal distribution with mean $0$ and standard deviation $\sigma$, defined as:
#
# $$
# \Phi (x , \sigma) = \frac{1}{\sigma \sqrt{2 \pi}} \int_{- \infty}^{x} e^{-\frac{t^2}{2 \sigma^2}} dt \ .
# $$
#
# For convenience, let's also define:
#
# $$
# \Phi (a, b; \sigma) = \Phi (b, \sigma) - \Phi (a, \sigma) = \frac{1}{\sigma \sqrt{2 \pi}} \int_{a}^{b} e^{-\frac{t^2}{2 \sigma^2}} dt \ .
# $$
#
# The cumulative distribution function of a discrete (integer) gaussian is written as:
#
# $$
# \Phi_{d} (n_1, n_2; \sigma) = \mathcal{N}_{d}(n_1, \sigma) + \mathcal{N}_{d}(n_1 + 1, \sigma) + \dots + \mathcal{N}_{d}(n_2, \sigma) \ .
# $$
#
# With the above definitions, we can define the probability density function of a truncated discrete (integer) normal distribution between $n_1$ and $n_2$ as:
#
# $$
# \mathcal{N_{d, t}}(n, n_1, n_2; \sigma) = \frac{\mathcal{N_{d}}(n, \sigma)}{\Phi_{d} (n_1, n_2; \sigma)} \ .
# $$

# %% [markdown]
# # Single vertex random walk
#
# Here I build a version of random walk over LQG intertwiners of a single 4-simplex.

# %%
using JupyterFormatter
enable_autoformat()
# Out:
# 1-element Vector{Function}:
#  format_current_cell (generic function with 1 method)

# %%
#using Distributed

# %%
#if (nprocs() == 1)
#    addprocs(4)
#end
#println("there are $(nprocs()) processes and $(nworkers()) workers")

# %%
using HalfIntegers,
    JLD2, ElasticArrays, Distributions, Random, StatsBase, DataFrames, CSV, Dates

# %%
function VertexMCMC(
    j::Float64,
    D::Int64,
    A::Array{Float64,5},
    N::Int64,
    batch_size::Int64,
    b::Int64,
    σ::Float64,
    draws_folder::String,
    verbosity::Int64,
)

    if (N % batch_size != 0)
        error("Number of iterations must be a multiple of batch size ")
    end

    draws = ElasticArray{Int64}(undef, 6, 0)
    Truncated_Coefficients = zeros(Float64, D)
    Normal_distribution = Normal(0, σ)

    d = D - 1

    for i = 0:d
        r = 0.0
        for n = (-i):1:(d-i)
            r += (cdf(Normal_distribution, n + 0.5) - cdf(Normal_distribution, n - 0.5))
        end
        Truncated_Coefficients[i+1] = r
    end

    if (verbosity > 1)
        println("\nTruncated coefficients for j=$(j) are $(Truncated_Coefficients)\n")
    end

    # Initial draw and gaussian 
    draw = Array{Int64}(undef, 6)           # 1 final slot for multiplicity
    gaussian_draw = Array{Int64}(undef, 5)

    amp = 0.0
    while (amp == 0)
        for i = 1:5
            draw[i] = rand((1:D))
        end
        amp = A[draw[1], draw[2], draw[3], draw[4], draw[5]]
    end

    draw[6] = 1 # Initial multiplicity      

    if (verbosity > 1)
        println("Initial draw is $(draw[1:5]) with amp $(amp)\n")
    end

    # Proposed draw  
    prop_draw = Array{Int64}(undef, 5)

    acceptance_ratio = 0
    multiplicity = 1                              # initial multiplicity counter
    draw_float_sample = Array{Float64}(undef, 1)   # some allocations --- Distribution pkg does not allow it to be scalar without allocating memory     

    RW_monitor = true  # to test if the RW actually moved

    df_all_batches = DataFrame([[], []], ["acceptance rate (%)", "run time (s)"])
    batch_counter = 0

    for n = 1:1:N

        if (verbosity > 1)
            println(
                "Iteration $(n)---------------------------------------------------------------\n",
            )
        end

        T_in = time_ns()

        if (n % batch_size == 0)

            if (verbosity > 1)
                println("$(n) iterations reached, time to store $(batch_size) draws\n")
            end

            resize!(draws, 6, size(draws)[2] + 1)
            #draw[6] = multiplicity
            draws[1:5, end] .= draw[1:5] .- 1
            draws[6, end] = multiplicity

            if (verbosity > 1)
                println(
                    "The last draw $(draw[1:5]) has been stored with multiplicity $(draw[6])\n",
                )
            end

            acceptance_percentage = acceptance_ratio * 100 / batch_size

            println(
                "$(acceptance_percentage)% of proposed draws have been accepted in this batch (in master chain)\n",
            )

            batch_counter += 1

            CSV.write(
                "$(draws_folder)/draws_batch_n_$(batch_counter).csv",
                DataFrame(
                    transpose(draws),
                    [
                        "intertwiner 1",
                        "intertwiner 2",
                        "intertwiner 3",
                        "intertwiner 4",
                        "intertwiner 5",
                        "multiplicity",
                    ],
                ),
            )

            T_fin = time_ns()

            push!(
                df_all_batches,
                [acceptance_percentage, round((T_fin - T_in) * 10^(-9), digits = 4)],
            )

            acceptance_ratio = 0
            multiplicity = 1
            resize!(draws, 6, 0)

            if (n == N)
                CSV.write("$(draws_folder)/statistics_batches.csv", df_all_batches)
            end

            continue

        end

        RW_monitor = true

        # Sampling proposed draw   
        Cx = Cx_prop = 1.0
        for i = 1:1:5
            while true
                rand!(Normal_distribution, draw_float_sample)
                @inbounds gaussian_draw[i] = round(Int64, draw_float_sample[1])
                @inbounds prop_draw[i] = draw[i] + gaussian_draw[i]
                @inbounds !(1 <= prop_draw[i] && prop_draw[i] <= (D)) || break
            end
            if (gaussian_draw[i] != 0)
                RW_monitor = false
            end
            @inbounds Cx *= Truncated_Coefficients[draw[i]]
            @inbounds Cx_prop *= Truncated_Coefficients[prop_draw[i]]
        end

        if (RW_monitor == true)

            if (verbosity > 1)
                println(
                    "The prop_draw below:\n$(prop_draw[1:5])\nturns out to be equal to the current draw:\n$(draw[1:5])\nso that the multiplicity of the current draw is raised to $(multiplicity + 1)\n",
                )
            end

            acceptance_ratio += 1
            multiplicity += 1

            continue

        else

            if (verbosity > 1)
                println(
                    "draw is:\n$(draw[1:5])\nprop_draw is:\n$(prop_draw[1:5])\namp is $(amp)\n",
                )
            end


            Prop_amp =
                A[prop_draw[1], prop_draw[2], prop_draw[3], prop_draw[4], prop_draw[5]]

            p = min(1.0, (((Prop_amp^2) / (amp^2))) * (Cx / Cx_prop))

            if (isnan(p))
                error(
                    "got NaN while computing densities ratio: prop_draw = $(prop_draw), amp = $(amp)",
                )
            end

            r = rand()

            if (r < p)

                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was accepted, since p=$(p) and r=$(r)\n",
                    )
                end

                if (n > b)

                    resize!(draws, 6, size(draws)[2] + 1)
                    #draw[6] = multiplicity
                    draws[1:5, end] .= draw[1:5] .- 1
                    draws[6, end] = multiplicity

                    if (verbosity > 1)
                        println(
                            "The old draw $(draw[1:5]) has been stored with multiplicity $(draw[6])\n",
                        )
                    end

                end

                multiplicity = 1

                for i = 1:5
                    draw[i] = prop_draw[i]
                end

                amp = Prop_amp
                acceptance_ratio += 1

                if (verbosity > 1)
                    println("Now the new draw is $(draw[1:5])\nthe new amp is $(amp)\n")
                end
            else
                multiplicity += 1
                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was rejected, since p=$(p) and r=$(r)\nThe current draw $(draw[1:5]) remains the same and its multiplicity is $(multiplicity)\namp remains $(amp)\n",
                    )
                end
            end

        end

    end

end
# Out:
# VertexMCMC (generic function with 1 method)

# %%
N = 10^7
batch_size = 10^6
b = 0
σ = 0.8
draws_folder_base = "../../data/MCMC/vertex/iterations_$(N)_batch_size_$(batch_size)_burnin_$(b)_sigma_$(σ)"
verbosity = 0

for j = 0.5:0.5:6.0

    local draws_folder = "$(draws_folder_base)/j_$(j)/draws"
    mkpath(draws_folder)

    D = Int(2j + 1)
    @load "../../data/EPRL_vertices/Julia/Dl_20/vertex_j_$(j).jld2" vertex
    @time VertexMCMC(j, D, vertex, N, batch_size, b, σ, draws_folder, verbosity)

end
# Out:
# 46.3748% of proposed draws have been accepted in this batch (in master chain)
#
# 46.3953% of proposed draws have been accepted in this batch (in master chain)
#
# 46.4322% of proposed draws have been accepted in this batch (in master chain)
#
# 46.3712% of proposed draws have been accepted in this batch (in master chain)
#
# 46.3318% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2571% of proposed draws have been accepted in this batch (in master chain)
#
# 46.4114% of proposed draws have been accepted in this batch (in master chain)
#
# 46.3508% of proposed draws have been accepted in this batch (in master chain)
#
# 46.4537% of proposed draws have been accepted in this batch (in master chain)
#
# 46.3196% of proposed draws have been accepted in this batch (in master chain)
#
#  10.324141 seconds (142.33 M allocations: 4.144 GiB, 8.29% gc time, 23.32% compilation time)
# 43.7295% of proposed draws have been accepted in this batch (in master chain)
#
# 43.7282% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8072% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8674% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8753% of proposed draws have been accepted in this batch (in master chain)
#
# 44.0268% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8919% of proposed draws have been accepted in this batch (in master chain)
#
# 44.0712% of proposed draws have been accepted in this batch (in master chain)
#
# 43.7742% of proposed draws have been accepted in this batch (in master chain)
#
# 43.923% of proposed draws have been accepted in this batch (in master chain)
#
#   8.445671 seconds (144.67 M allocations: 3.996 GiB, 8.36% gc time)
# 38.4335% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3942% of proposed draws have been accepted in this batch (in master chain)
#
# 38.2378% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3699% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3303% of proposed draws have been accepted in this batch (in master chain)
#
# 38.1754% of proposed draws have been accepted in this batch (in master chain)
#
# 38.411% of proposed draws have been accepted in this batch (in master chain)
#
# 38.2904% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3786% of proposed draws have been accepted in this batch (in master chain)
#
# 38.274% of proposed draws have been accepted in this batch (in master chain)
#
#   7.273033 seconds (128.22 M allocations: 3.549 GiB, 7.74% gc time)
# 35.7813% of proposed draws have been accepted in this batch (in master chain)
#
# 35.839% of proposed draws have been accepted in this batch (in master chain)
#
# 35.8897% of proposed draws have been accepted in this batch (in master chain)
#
# 35.7818% of proposed draws have been accepted in this batch (in master chain)
#
# 35.8505% of proposed draws have been accepted in this batch (in master chain)
#
# 35.9598% of proposed draws have been accepted in this batch (in master chain)
#
# 35.7122% of proposed draws have been accepted in this batch (in master chain)
#
# 35.8294% of proposed draws have been accepted in this batch (in master chain)
#
# 35.7793% of proposed draws have been accepted in this batch (in master chain)
#
# 35.6396% of proposed draws have been accepted in this batch (in master chain)
#
#   6.692299 seconds (120.63 M allocations: 3.342 GiB, 7.67% gc time)
# 36.5229% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4717% of proposed draws have been accepted in this batch (in master chain)
#
# 36.3017% of proposed draws have been accepted in this batch (in master chain)
#
# 35.959% of proposed draws have been accepted in this batch (in master chain)
#
# 36.1584% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0737% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0405% of proposed draws have been accepted in this batch (in master chain)
#
# 36.1096% of proposed draws have been accepted in this batch (in master chain)
#
# 35.7787% of proposed draws have been accepted in this batch (in master chain)
#
# 36.1582% of proposed draws have been accepted in this batch (in master chain)
#
#   6.816164 seconds (123.52 M allocations: 3.421 GiB, 8.39% gc time)
# 36.4402% of proposed draws have been accepted in this batch (in master chain)
#
# 36.3788% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2097% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2964% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0023% of proposed draws have been accepted in this batch (in master chain)
#
# 35.9622% of proposed draws have been accepted in this batch (in master chain)
#
# 36.1576% of proposed draws have been accepted in this batch (in master chain)
#
# 35.6857% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2103% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4493% of proposed draws have been accepted in this batch (in master chain)
#
#   7.016773 seconds (124.54 M allocations: 3.449 GiB, 8.04% gc time)
# 36.5573% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2583% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4802% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2699% of proposed draws have been accepted in this batch (in master chain)
#
# 35.7137% of proposed draws have been accepted in this batch (in master chain)
#
# 35.9729% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4912% of proposed draws have been accepted in this batch (in master chain)
#
# 36.7377% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2812% of proposed draws have been accepted in this batch (in master chain)
#
# 36.5319% of proposed draws have been accepted in this batch (in master chain)
#
#   6.897183 seconds (125.75 M allocations: 3.482 GiB, 8.06% gc time)
# 37.2046% of proposed draws have been accepted in this batch (in master chain)
#
# 36.9847% of proposed draws have been accepted in this batch (in master chain)
#
# 37.274% of proposed draws have been accepted in this batch (in master chain)
#
# 36.8918% of proposed draws have been accepted in this batch (in master chain)
#
# 36.746% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5434% of proposed draws have been accepted in this batch (in master chain)
#
# 36.8787% of proposed draws have been accepted in this batch (in master chain)
#
# 37.2705% of proposed draws have been accepted in this batch (in master chain)
#
# 36.9771% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5068% of proposed draws have been accepted in this batch (in master chain)
#
#   7.073247 seconds (129.64 M allocations: 3.587 GiB, 7.78% gc time)
# 38.0185% of proposed draws have been accepted in this batch (in master chain)
#
# 37.4702% of proposed draws have been accepted in this batch (in master chain)
#
# 37.6469% of proposed draws have been accepted in this batch (in master chain)
#
# 37.1876% of proposed draws have been accepted in this batch (in master chain)
#
# 36.738% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5985% of proposed draws have been accepted in this batch (in master chain)
#
# 37.2659% of proposed draws have been accepted in this batch (in master chain)
#
# 37.4763% of proposed draws have been accepted in this batch (in master chain)
#
# 37.8382% of proposed draws have been accepted in this batch (in master chain)
#
# 37.9134% of proposed draws have been accepted in this batch (in master chain)
#
#   7.069805 seconds (131.58 M allocations: 3.640 GiB, 6.40% gc time)
# 37.265% of proposed draws have been accepted in this batch (in master chain)
#
# 37.7196% of proposed draws have been accepted in this batch (in master chain)
#
# 37.3305% of proposed draws have been accepted in this batch (in master chain)
#
# 37.4315% of proposed draws have been accepted in this batch (in master chain)
#
# 37.6576% of proposed draws have been accepted in this batch (in master chain)
#
# 37.4338% of proposed draws have been accepted in this batch (in master chain)
#
# 37.9516% of proposed draws have been accepted in this batch (in master chain)
#
# 37.8717% of proposed draws have been accepted in this batch (in master chain)
#
# 37.7373% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3213% of proposed draws have been accepted in this batch (in master chain)
#
#   7.445785 seconds (132.35 M allocations: 3.661 GiB, 7.77% gc time)
# 38.2474% of proposed draws have been accepted in this batch (in master chain)
#
# 38.0523% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3165% of proposed draws have been accepted in this batch (in master chain)
#
# 38.4057% of proposed draws have been accepted in this batch (in master chain)
#
# 39.5485% of proposed draws have been accepted in this batch (in master chain)
#
# 39.0422% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3476% of proposed draws have been accepted in this batch (in master chain)
#
# 37.217% of proposed draws have been accepted in this batch (in master chain)
#
# 38.0356% of proposed draws have been accepted in this batch (in master chain)
#
# 36.9894% of proposed draws have been accepted in this batch (in master chain)
#
#   7.469126 seconds (134.79 M allocations: 3.728 GiB, 9.28% gc time)
# 39.1154% of proposed draws have been accepted in this batch (in master chain)
#
# 39.1093% of proposed draws have been accepted in this batch (in master chain)
#
# 38.7012% of proposed draws have been accepted in this batch (in master chain)
#
# 38.9699% of proposed draws have been accepted in this batch (in master chain)
#
# 38.6225% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3026% of proposed draws have been accepted in this batch (in master chain)
#
# 38.546% of proposed draws have been accepted in this batch (in master chain)
#
# 39.0934% of proposed draws have been accepted in this batch (in master chain)
#
# 38.8323% of proposed draws have been accepted in this batch (in master chain)
#
# 37.7625% of proposed draws have been accepted in this batch (in master chain)
#   7.396943 seconds (137.02 M allocations: 3.788 GiB, 7.42% gc time, 0.59% compilation time)

# %% [markdown]
# # Star random walk
#
# Here I build a version of random walk over LQG intertwiners of the star model.

# %%
using LoopVectorization
# Out:
# ┌ Warning: Module Preferences with build ID 340633049594401 is missing from the cache.
# │ This may mean Preferences [21216c6a-2e73-6563-6e65-726566657250] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Preferences with build ID 340633049594401 is missing from the cache.
# │ This may mean Preferences [21216c6a-2e73-6563-6e65-726566657250] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Preferences with build ID 340633049594401 is missing from the cache.
# │ This may mean Preferences [21216c6a-2e73-6563-6e65-726566657250] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Preferences with build ID 340633049594401 is missing from the cache.
# │ This may mean Preferences [21216c6a-2e73-6563-6e65-726566657250] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Preferences with build ID 340633049594401 is missing from the cache.
# │ This may mean Preferences [21216c6a-2e73-6563-6e65-726566657250] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Preferences with build ID 340633049594401 is missing from the cache.
# │ This may mean Preferences [21216c6a-2e73-6563-6e65-726566657250] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Preferences with build ID 340633049594401 is missing from the cache.
# │ This may mean Preferences [21216c6a-2e73-6563-6e65-726566657250] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module ArrayInterfaceCore with build ID 602754413460014 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module ArrayInterfaceCore with build ID 602754413460014 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module ArrayInterfaceCore with build ID 602754413460014 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module ArrayInterface with build ID 602757950797819 is missing from the cache.
# │ This may mean ArrayInterface [4fba245c-0d91-5ea0-9b3e-6abc04ee57a9] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module ArrayInterface with build ID 602757950797819 is missing from the cache.
# │ This may mean ArrayInterface [4fba245c-0d91-5ea0-9b3e-6abc04ee57a9] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Adapt with build ID 340632478760701 is missing from the cache.
# │ This may mean Adapt [79e6a3ab-5dfb-504d-930d-738a2a938a0e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module Adapt with build ID 340632478760701 is missing from the cache.
# │ This may mean Adapt [79e6a3ab-5dfb-504d-930d-738a2a938a0e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module ArrayInterfaceCore with build ID 602754413460014 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module VectorizationBase with build ID 602757354506718 is missing from the cache.
# │ This may mean VectorizationBase [3d5dd08c-fd9d-11e8-17fa-ed2836048c2f] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module ArrayInterface with build ID 602757950797819 is missing from the cache.
# │ This may mean ArrayInterface [4fba245c-0d91-5ea0-9b3e-6abc04ee57a9] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module IrrationalConstants with build ID 340632419034401 is missing from the cache.
# │ This may mean IrrationalConstants [92d709cd-6900-40b7-9082-c6be49f344b6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module IrrationalConstants with build ID 340632419034401 is missing from the cache.
# │ This may mean IrrationalConstants [92d709cd-6900-40b7-9082-c6be49f344b6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module IrrationalConstants with build ID 340632419034401 is missing from the cache.
# │ This may mean IrrationalConstants [92d709cd-6900-40b7-9082-c6be49f344b6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107
# ┌ Warning: Module MacroTools with build ID 340632839990901 is missing from the cache.
# │ This may mean MacroTools [1914dd2f-81c6-5fcd-8719-6d5c9610ff09] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1107

# %%
# computes star amplitude for given dimensions, vertex amplitude, containers for contraction and indices
function star_amplitude(D, A, v1, v2, v3, v4, v5, indices)

    @turbo for i = 1:D

        v1[i] = A[i, indices[1], indices[2], indices[3], indices[4]]
        v2[i] = A[i, indices[5], indices[6], indices[7], indices[8]]
        v3[i] = A[i, indices[9], indices[10], indices[11], indices[12]]
        v4[i] = A[i, indices[13], indices[14], indices[15], indices[16]]
        v5[i] = A[i, indices[17], indices[18], indices[19], indices[20]]

    end

    s = 0.0

    @turbo for q = 1:D, l = 1:D, k = 1:D, j = 1:D, m = 1:D
        s += A[m, j, k, l, q] * v1[q] * v2[l] * v3[k] * v4[j] * v5[m]
    end
    return s

end
# Out:
# star_amplitude (generic function with 1 method)

# %%
function StarMCMC(
    j::Float64,
    D::Int64,
    A::Array{Float64,5},
    N::Int64,
    batch_size::Int64,
    b::Int64,
    σ::Float64,
    draws_folder::String,
    verbosity::Int64,
)

    # containers for contraction
    v1 = zeros(Float64, D)
    v2 = zeros(Float64, D)
    v3 = zeros(Float64, D)
    v4 = zeros(Float64, D)
    v5 = zeros(Float64, D)

    if (N % batch_size != 0)
        error("Number of iterations must be a multiple of batch size ")
    end

    draws = ElasticArray{Int64}(undef, 21, 0)
    Truncated_Coefficients = zeros(Float64, D)
    Normal_distribution = Normal(0, σ)

    d = D - 1

    for i = 0:d
        r = 0.0
        for n = (-i):1:(d-i)
            r += (cdf(Normal_distribution, n + 0.5) - cdf(Normal_distribution, n - 0.5))
        end
        Truncated_Coefficients[i+1] = r
    end

    if (verbosity > 1)
        println("\nTruncated coefficients for j=$(j) are $(Truncated_Coefficients)\n")
    end

    # Initial draw and gaussian 
    draw = Array{Int64}(undef, 21)           # 1 final slot for multiplicity
    gaussian_draw = Array{Int64}(undef, 20)

    amp = 0.0
    while (amp == 0)
        for i = 1:20
            draw[i] = rand((1:D))
        end
        amp = star_amplitude(D, A, v1, v2, v3, v4, v5, draw)
    end

    draw[6] = 1 # Initial multiplicity      

    if (verbosity > 1)
        println("Initial draw is $(draw[1:20]) with amp $(amp)\n")
    end

    # Proposed draw  
    prop_draw = Array{Int64}(undef, 20)

    acceptance_ratio = 0
    multiplicity = 1                              # initial multiplicity counter
    draw_float_sample = Array{Float64}(undef, 1)   # some allocations --- Distribution pkg does not allow it to be scalar without allocating memory     

    RW_monitor = true  # to test if the RW actually moved

    df_all_batches = DataFrame([[], []], ["acceptance rate (%)", "run time (s)"])
    batch_counter = 0

    for n = 1:1:N

        if (verbosity > 1)
            println(
                "Iteration $(n)---------------------------------------------------------------\n",
            )
        end

        T_in = time_ns()

        if (n % batch_size == 0)

            if (verbosity > 1)
                println("$(n) iterations reached, time to store $(batch_size) draws\n")
            end

            resize!(draws, 21, size(draws)[2] + 1)

            draws[1:20, end] .= draw[1:20] .- 1
            draws[21, end] = multiplicity

            if (verbosity > 1)
                println(
                    "The last draw $(draw[1:20]) has been stored with multiplicity $(draw[6])\n",
                )
            end

            acceptance_percentage = acceptance_ratio * 100 / batch_size

            println(
                "$(acceptance_percentage)% of proposed draws have been accepted in this batch (in master chain)\n",
            )

            batch_counter += 1

            CSV.write(
                "$(draws_folder)/draws_batch_n_$(batch_counter).csv",
                DataFrame(
                    transpose(draws),
                    [
                        "intertwiner 1",
                        "intertwiner 2",
                        "intertwiner 3",
                        "intertwiner 4",
                        "intertwiner 5",
                        "intertwiner 6",
                        "intertwiner 7",
                        "intertwiner 8",
                        "intertwiner 9",
                        "intertwiner 10",
                        "intertwiner 11",
                        "intertwiner 12",
                        "intertwiner 13",
                        "intertwiner 14",
                        "intertwiner 15",
                        "intertwiner 16",
                        "intertwiner 17",
                        "intertwiner 18",
                        "intertwiner 19",
                        "intertwiner 20",
                        "multiplicity",
                    ],
                ),
            )

            T_fin = time_ns()

            push!(
                df_all_batches,
                [acceptance_percentage, round((T_fin - T_in) * 10^(-9), digits = 4)],
            )

            acceptance_ratio = 0
            multiplicity = 1
            resize!(draws, 21, 0)

            if (n == N)
                CSV.write("$(draws_folder)/statistics_batches.csv", df_all_batches)
            end

            continue

        end

        RW_monitor = true

        # Sampling proposed draw   
        Cx = Cx_prop = 1.0
        for i = 1:20
            while true
                rand!(Normal_distribution, draw_float_sample)
                @inbounds gaussian_draw[i] = round(Int64, draw_float_sample[1])
                @inbounds prop_draw[i] = draw[i] + gaussian_draw[i]
                @inbounds !(1 <= prop_draw[i] && prop_draw[i] <= (D)) || break
            end
            if (gaussian_draw[i] != 0)
                RW_monitor = false
            end
            @inbounds Cx *= Truncated_Coefficients[draw[i]]
            @inbounds Cx_prop *= Truncated_Coefficients[prop_draw[i]]
        end

        if (RW_monitor == true)

            if (verbosity > 1)
                println(
                    "The prop_draw below:\n$(prop_draw[1:20])\nturns out to be equal to the current draw:\n$(draw[1:20])\nso that the multiplicity of the current draw is raised to $(multiplicity + 1)\n",
                )
            end

            acceptance_ratio += 1
            multiplicity += 1

            continue

        else

            if (verbosity > 1)
                println(
                    "draw is:\n$(draw[1:20])\nprop_draw is:\n$(prop_draw[1:20])\namp is $(amp)\n",
                )
            end


            Prop_amp = star_amplitude(D, A, v1, v2, v3, v4, v5, prop_draw)

            p = min(1.0, (((Prop_amp^2) / (amp^2))) * (Cx / Cx_prop))

            if (isnan(p))
                error(
                    "got NaN while computing densities ratio: prop_draw = $(prop_draw), amp = $(amp)",
                )
            end

            r = rand()

            if (r < p)

                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was accepted, since p=$(p) and r=$(r)\n",
                    )
                end

                if (n > b)

                    resize!(draws, 21, size(draws)[2] + 1)

                    draws[1:20, end] .= draw[1:20] .- 1
                    draws[21, end] = multiplicity

                    if (verbosity > 1)
                        println(
                            "The old draw $(draw[1:20]) has been stored with multiplicity $(draw[21])\n",
                        )
                    end

                end

                multiplicity = 1

                for i = 1:20
                    draw[i] = prop_draw[i]
                end

                amp = Prop_amp
                acceptance_ratio += 1

                if (verbosity > 1)
                    println("Now the new draw is $(draw[1:20])\nthe new amp is $(amp)\n")
                end
            else
                multiplicity += 1
                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was rejected, since p=$(p) and r=$(r)\nThe current draw $(draw[1:20]) remains the same and its multiplicity is $(multiplicity)\namp remains $(amp)\n",
                    )
                end
            end

        end

    end

end
# Out:
# StarMCMC (generic function with 1 method)

# %%
N = 10^6
batch_size = 10^5
b = 0
σ = 0.4
draws_folder_base = "../../data/MCMC/star/iterations_$(N)_batch_size_$(batch_size)_burnin_$(b)_sigma_$(σ)"
verbosity = 0

for j = 0.5:0.5:6.0

    local draws_folder = "$(draws_folder_base)/j_$(j)/draws"
    mkpath(draws_folder)

    D = Int(2j + 1)
    @load "../../data/EPRL_vertices/Julia/Dl_20/vertex_j_$(j).jld2" vertex
    @time StarMCMC(j, D, vertex, N, batch_size, b, σ, draws_folder, verbosity)

end
# Out:
# 29.218% of proposed draws have been accepted in this batch (in master chain)
#
# 29.366% of proposed draws have been accepted in this batch (in master chain)
#
# 29.403% of proposed draws have been accepted in this batch (in master chain)
#
# 28.973% of proposed draws have been accepted in this batch (in master chain)
#
# 29.156% of proposed draws have been accepted in this batch (in master chain)
#
# 28.157% of proposed draws have been accepted in this batch (in master chain)
#
# 28.941% of proposed draws have been accepted in this batch (in master chain)
#
# 28.879% of proposed draws have been accepted in this batch (in master chain)
#
# 29.302% of proposed draws have been accepted in this batch (in master chain)
#
# 28.484% of proposed draws have been accepted in this batch (in master chain)
#
#  19.293607 seconds (52.77 M allocations: 2.144 GiB, 4.57% gc time, 90.02% compilation time)
# 29.306% of proposed draws have been accepted in this batch (in master chain)
#
# 28.592% of proposed draws have been accepted in this batch (in master chain)
#
# 28.754% of proposed draws have been accepted in this batch (in master chain)
#
# 29.74% of proposed draws have been accepted in this batch (in master chain)
#
# 28.994% of proposed draws have been accepted in this batch (in master chain)
#
# 28.985% of proposed draws have been accepted in this batch (in master chain)
#
# 29.006% of proposed draws have been accepted in this batch (in master chain)
#
# 28.053% of proposed draws have been accepted in this batch (in master chain)
#
# 28.837% of proposed draws have been accepted in this batch (in master chain)
#
# 28.763% of proposed draws have been accepted in this batch (in master chain)
#
#   2.045592 seconds (31.20 M allocations: 926.796 MiB, 5.63% gc time)
# 24.475% of proposed draws have been accepted in this batch (in master chain)
#
# 26.026% of proposed draws have been accepted in this batch (in master chain)
#
# 24.594% of proposed draws have been accepted in this batch (in master chain)
#
# 26.264% of proposed draws have been accepted in this batch (in master chain)
#
# 25.6% of proposed draws have been accepted in this batch (in master chain)
#
# 24.701% of proposed draws have been accepted in this batch (in master chain)
#
# 24.887% of proposed draws have been accepted in this batch (in master chain)
#
# 24.83% of proposed draws have been accepted in this batch (in master chain)
#
# 25.724% of proposed draws have been accepted in this batch (in master chain)
#
# 24.647% of proposed draws have been accepted in this batch (in master chain)
#
#   2.087623 seconds (27.76 M allocations: 830.150 MiB, 5.85% gc time)
# 23.249% of proposed draws have been accepted in this batch (in master chain)
#
# 23.67% of proposed draws have been accepted in this batch (in master chain)
#
# 24.895% of proposed draws have been accepted in this batch (in master chain)
#
# 24.255% of proposed draws have been accepted in this batch (in master chain)
#
# 24.17% of proposed draws have been accepted in this batch (in master chain)
#
# 24.689% of proposed draws have been accepted in this batch (in master chain)
#
# 24.973% of proposed draws have been accepted in this batch (in master chain)
#
# 24.508% of proposed draws have been accepted in this batch (in master chain)
#
# 24.669% of proposed draws have been accepted in this batch (in master chain)
#
# 23.653% of proposed draws have been accepted in this batch (in master chain)
#
#   2.684146 seconds (27.23 M allocations: 815.396 MiB, 4.06% gc time)
# 24.879% of proposed draws have been accepted in this batch (in master chain)
#
# 23.632% of proposed draws have been accepted in this batch (in master chain)
#
# 25.086% of proposed draws have been accepted in this batch (in master chain)
#
# 24.648% of proposed draws have been accepted in this batch (in master chain)
#
# 26.084% of proposed draws have been accepted in this batch (in master chain)
#
# 25.363% of proposed draws have been accepted in this batch (in master chain)
#
# 23.722% of proposed draws have been accepted in this batch (in master chain)
#
# 25.406% of proposed draws have been accepted in this batch (in master chain)
#
# 25.703% of proposed draws have been accepted in this batch (in master chain)
#
# 24.912% of proposed draws have been accepted in this batch (in master chain)
#
#   3.622194 seconds (28.31 M allocations: 845.507 MiB, 2.97% gc time)
# 23.765% of proposed draws have been accepted in this batch (in master chain)
#
# 25.288% of proposed draws have been accepted in this batch (in master chain)
#
# 25.875% of proposed draws have been accepted in this batch (in master chain)
#
# 25.407% of proposed draws have been accepted in this batch (in master chain)
#
# 25.77% of proposed draws have been accepted in this batch (in master chain)
#
# 25.198% of proposed draws have been accepted in this batch (in master chain)
#
# 25.458% of proposed draws have been accepted in this batch (in master chain)
#
# 24.622% of proposed draws have been accepted in this batch (in master chain)
#
# 27.587% of proposed draws have been accepted in this batch (in master chain)
#
# 25.147% of proposed draws have been accepted in this batch (in master chain)
#
#   5.043249 seconds (29.08 M allocations: 867.386 MiB, 2.48% gc time)
# 25.558% of proposed draws have been accepted in this batch (in master chain)
#
# 27.433% of proposed draws have been accepted in this batch (in master chain)
#
# 24.0% of proposed draws have been accepted in this batch (in master chain)
#
# 25.888% of proposed draws have been accepted in this batch (in master chain)
#
# 26.275% of proposed draws have been accepted in this batch (in master chain)
#
# 26.352% of proposed draws have been accepted in this batch (in master chain)
#
# 27.168% of proposed draws have been accepted in this batch (in master chain)
#
# 26.137% of proposed draws have been accepted in this batch (in master chain)
#
# 24.806% of proposed draws have been accepted in this batch (in master chain)
#
# 27.531% of proposed draws have been accepted in this batch (in master chain)
#
#   7.375988 seconds (30.12 M allocations: 896.552 MiB, 1.83% gc time)
# 22.565% of proposed draws have been accepted in this batch (in master chain)
#
# 25.043% of proposed draws have been accepted in this batch (in master chain)
#
# 27.51% of proposed draws have been accepted in this batch (in master chain)
#
# 26.9% of proposed draws have been accepted in this batch (in master chain)
#
# 27.045% of proposed draws have been accepted in this batch (in master chain)
#
# 24.223% of proposed draws have been accepted in this batch (in master chain)
#
# 27.128% of proposed draws have been accepted in this batch (in master chain)
#
# 28.707% of proposed draws have been accepted in this batch (in master chain)
#
# 26.965% of proposed draws have been accepted in this batch (in master chain)
#
# 27.756% of proposed draws have been accepted in this batch (in master chain)
#
#  14.489133 seconds (30.49 M allocations: 906.844 MiB, 0.81% gc time)
# 28.181% of proposed draws have been accepted in this batch (in master chain)
#
# 26.066% of proposed draws have been accepted in this batch (in master chain)
#
# 25.055% of proposed draws have been accepted in this batch (in master chain)
#
# 28.518% of proposed draws have been accepted in this batch (in master chain)
#
# 30.201% of proposed draws have been accepted in this batch (in master chain)
#
# 25.716% of proposed draws have been accepted in this batch (in master chain)
#
# 26.606% of proposed draws have been accepted in this batch (in master chain)
#
# 27.817% of proposed draws have been accepted in this batch (in master chain)
#
# 30.602% of proposed draws have been accepted in this batch (in master chain)
#
# 31.357% of proposed draws have been accepted in this batch (in master chain)
#
#  23.427744 seconds (32.79 M allocations: 971.274 MiB, 1.26% gc time)
# 22.369% of proposed draws have been accepted in this batch (in master chain)
#
# 25.081% of proposed draws have been accepted in this batch (in master chain)
#
# 27.67% of proposed draws have been accepted in this batch (in master chain)
#
# 26.363% of proposed draws have been accepted in this batch (in master chain)
#
# 25.025% of proposed draws have been accepted in this batch (in master chain)
#
# 31.293% of proposed draws have been accepted in this batch (in master chain)
#
# 31.29% of proposed draws have been accepted in this batch (in master chain)
#
# 29.309% of proposed draws have been accepted in this batch (in master chain)
#
# 26.576% of proposed draws have been accepted in this batch (in master chain)
#
# 25.557% of proposed draws have been accepted in this batch (in master chain)
#
#  34.255952 seconds (31.53 M allocations: 936.004 MiB, 0.28% gc time)
# 25.06% of proposed draws have been accepted in this batch (in master chain)
#
# 27.379% of proposed draws have been accepted in this batch (in master chain)
#
# 30.725% of proposed draws have been accepted in this batch (in master chain)
#
# 28.808% of proposed draws have been accepted in this batch (in master chain)
#
# 26.986% of proposed draws have been accepted in this batch (in master chain)
#
# 31.436% of proposed draws have been accepted in this batch (in master chain)
#
# 28.922% of proposed draws have been accepted in this batch (in master chain)
#
# 29.567% of proposed draws have been accepted in this batch (in master chain)
#
# 26.814% of proposed draws have been accepted in this batch (in master chain)
#
# 28.741% of proposed draws have been accepted in this batch (in master chain)
#
#  44.068946 seconds (33.47 M allocations: 990.493 MiB, 0.24% gc time)
# 32.372% of proposed draws have been accepted in this batch (in master chain)
#
# 28.888% of proposed draws have been accepted in this batch (in master chain)
#
# 28.586% of proposed draws have been accepted in this batch (in master chain)
#
# 30.345% of proposed draws have been accepted in this batch (in master chain)
#
# 31.511% of proposed draws have been accepted in this batch (in master chain)
#
# 30.78% of proposed draws have been accepted in this batch (in master chain)
#
# 29.628% of proposed draws have been accepted in this batch (in master chain)
#
# 31.5% of proposed draws have been accepted in this batch (in master chain)
#
# 27.827% of proposed draws have been accepted in this batch (in master chain)
#
# 29.685% of proposed draws have been accepted in this batch (in master chain)
#
#  77.548044 seconds (35.81 M allocations: 1.036 GiB, 0.14% gc time)

# %% [markdown]
# # OLD STUFF

# %% [markdown]
# ## Computing dihedral angles
#
# Let's compute the expectation value of the dihedral angle on the first node

# %%
function from_intertwiner_to_angle(i::Int64, j)
    return (i * (i + 1) - 2j * (j + 1)) / (2j * (j + 1))
end
# Out:
# from_intertwiner_to_angle (generic function with 1 method)

# %%
# not optimized

function angles_computation!(
    chains_to_assemble::Int64,
    angle_all_chains,
    angle_numerical_fluctuations,
    model::String,
    j::Float64,
    N,
    b,
    draws_folder::String,
)

    for chain_id = 1:chains_to_assemble

        @load "$(draws_folder)/ampls_chain=$(chain_id).jld2" ampls
        @load "$(draws_folder)/draws_chain=$(chain_id).jld2" draws
        number_of_elements_in_this_chain = size(ampls)[1]

        angle_this_chain = 0.0

        for i = 1:number_of_elements_in_this_chain
            angle_this_chain += from_intertwiner_to_angle(draws[i, 1] - 1, j) * draws[i, 6]
        end

        angle_this_chain /= (N - b)
        angle_all_chains[chain_id] = angle_this_chain

        # average_angle_first_node 
        angle_numerical_fluctuations[1] = mean(angle_all_chains[:])

        # std_dev_angle_first_node 
        angle_numerical_fluctuations[2] = std(angle_all_chains[:])

        # number of combined chains
        angle_numerical_fluctuations[3] = chains_to_assemble

    end

end
# Out:
# angles_computation! (generic function with 1 method)

# %%
using CSV, DataFrames

# %%
chains_to_assemble = nprocs()

N = 10^6
b = 0
σ = 0.9
draws_folder_base = "../data/MCMC/draws/N_$(N)_b_$(b)_$(σ)"
operator_folder_base = "../data/MCMC/operators/N_$(N)_b_$(b)_$(σ)"

for model in ["BF", "EPRL"]

    chain_id = myid()

    angle_fluctuations_table = DataFrame()

    # creating first column of angles numerical fluctuations dataframe 
    array = String[]
    push!(array, "avg. angles (first node)")
    push!(array, "std. angles (first node)")
    push!(array, "n. chains combined")

    angle_fluctuations_table = DataFrame(numerical_data = array)

    angle_all_chains = zeros(Float64, chains_to_assemble)
    angle_numerical_fluctuations = zeros(Float64, 3)

    for j = 0.5:0.5:6.0

        local draws_folder = "$(draws_folder_base)/$(model)/j_$(j)"

        column_name = "j=$(j)"

        # not optimized
        @time angles_computation!(
            chains_to_assemble,
            angle_all_chains,
            angle_numerical_fluctuations,
            model,
            j,
            N,
            b,
            draws_folder,
        )

        angle_numerical_fluctuations_dataframe =
            DataFrame(to_rename = angle_numerical_fluctuations)
        rename!(angle_numerical_fluctuations_dataframe, :to_rename => column_name)

        angle_fluctuations_table =
            hcat(angle_fluctuations_table, angle_numerical_fluctuations_dataframe)

    end

    local operator_folder = "$(operator_folder_base)/$(model)"
    mkpath(operator_folder)

    CSV.write(
        "$(operator_folder)/angles_numerical_fluctuations_table.csv",
        angle_fluctuations_table,
    )

end
# Out:
# UndefVarError: nprocs not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\Jared\OneDrive\Github\GFlowNets_on_SpinFoams\notebooks\Julia\MCMC.ipynb:1
