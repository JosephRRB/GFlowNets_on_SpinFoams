# %% [markdown]
# # Markov Chain Monte Carlo

# %% [markdown]
# Let's consider a quantity $O$ which can be computed as:
#
# $$
# O = \sum\limits_{x \in \chi} o \left( x \right) \tilde{f} \left( x \right) \ ,
# $$
#
# where $x$ is a (possibly multidimensional) discrete variable on a state space $\chi$ which must be summed over, while $\tilde{f}$ is a probability density function on $\chi$, so that $\sum\limits_{x \in \chi} \tilde{f} \left( x \right) = 1$. From now on, we define $\tilde{f}$ as the $\textbf{target}$ distribution and we omit the state space label $\chi$. Since the target distribution is normalized, we can write:
#
# $$
# \tilde{f} \left( x \right) \equiv \frac{f \left( x \right)}{\sum\limits_{x} f \left( x \right)} \ ,
# $$
#
# from which:
#
# $$
# O = \frac{ \sum\limits_{x} f \left( x \right) o \left( x \right) }{\sum\limits_{x} f \left( x \right)} \ .
# $$
#
# If the target distribution is computable up to a multiplying constant, the $\textbf{Metropolis–Hastings algorithm}$ allows to construct on state space $\chi$ an ergodic Markov chain with length $N_{MC}$: $x_{1} , \ x_{2} , \ x_{3} \dots , x_{n} \ \dots , x_{N_{MC}}$ such that $x_{n}$ is converging (in distribution) to $\tilde{f}$, exploring the space $\chi$ progressively. If we define:
#
# $$
# O_{N_{MC}} = \frac{1}{N_{MC}} \sum\limits_{i = 1}^{N_{MC}} o \left(x_i \right) \ ,
# $$
#
# then, since the chain can be considered as a statistical sample, the law of large numbers ensures that:
#
# $$
# \lim_{N_{MC} \to \infty} O_{N_{MC}}  = O \ ,
# $$
#
# which allows us to write:
#
# $$
# O_{N_{MC}} \approx O \hspace{3mm} \textrm{for $N_{MC} \gg 1$} \ .
# $$
#
# Namely, we end up with an estimate of the original sum. Since the simulation is Markovian and the chain itself can be considered as a statistical sample, the latter usually depends on the starting value. The initial steps are tipically removed as $\textbf{burn-in}$, when the chain is still in the so-called $\textbf{thermalization}$ phase.
#
# In order to transit from the value $x_{n}$ of the chain to the value $x_{n + 1}$, we require a $\textbf{proposal distribution}$ $q$ defined on space $\chi$. If $q$ is positive everywhere, then the Metropolis-Hastings algorithm preserves $\tilde{f}$ as the stationary distribution to which the chain is progressively converging.
#
# In the $\textbf{random walk Metropolis-Hastings}$, the proposal distribution consists in a local exploration of the neighborhood of the current value $x_n$ of the
# Markov chain. That is, the proposed value $y_n$ is simulated as:
#
# $$
# y_n = x_n + \epsilon_n \ ,
# $$
#
# where $\epsilon_n$ is a random perturbation with distribution $g$. As proposal distribution $g$, we focus on a discrete truncated normal distribution centered on $x_n$. A few relevant definitions are discussed next.
#
# Finally, since $x_n$ depends on the previous element along the Markov chain, this induces a non-zero correlation between $x_n$ and $x_{n+d}$. The correlation between $x_n$ and $x_{n+d}$ is defined as the $\textbf{autocorrelation}$ at lag $d$. For a Markov chain that converges to a stationary distribution, the autocorrelation should indeed decrease as the lag increases. The definition of the autocorrelation function between the chain elements $x_n$ and $x_{n+d}$ is defined as the expected value $\mathbb{E} \left(x_n x_{n+d} \right) $.
#
# ### Truncated normal distribution
#
# The probability density function of a normal distribution with mean $0$ and standard deviation $\sigma$ is defined as:
#
# $$
# \mathcal{N}(x, \sigma) = \frac{1}{\sigma \sqrt{2 \pi}}e^{-\frac{x^2}{2 \sigma^2}} \ ,
# $$
#
# where $x \in \mathbb{R}$. The probability density function of a normal distribution with mean $\mu$ is simply given by $\mathcal{N}(x - \mu, \sigma)$ .
#
#
# In the discrete (integer) case, we can define the probability density function of a normal distribution with mean $0$ and standard deviation $\sigma$ as:
#
# $$
# \mathcal{N}_{d}(n, \sigma) = \Phi ( n + 0.5, \sigma ) - \Phi (n - 0.5, \sigma ) \ ,
# $$
#
# where $n \in \mathbb{N}$ and $\Phi ( x, \sigma ) $ is the cumulative distribution function of a normal distribution with mean $0$ and standard deviation $\sigma$, defined as:
#
# $$
# \Phi (x , \sigma) = \frac{1}{\sigma \sqrt{2 \pi}} \int_{- \infty}^{x} e^{-\frac{t^2}{2 \sigma^2}} dt \ .
# $$
#
# For convenience, let's also define:
#
# $$
# \Phi (a, b; \sigma) = \Phi (b, \sigma) - \Phi (a, \sigma) = \frac{1}{\sigma \sqrt{2 \pi}} \int_{a}^{b} e^{-\frac{t^2}{2 \sigma^2}} dt \ .
# $$
#
# The cumulative distribution function of a discrete (integer) gaussian is written as:
#
# $$
# \Phi_{d} (n_1, n_2; \sigma) = \mathcal{N}_{d}(n_1, \sigma) + \mathcal{N}_{d}(n_1 + 1, \sigma) + \dots + \mathcal{N}_{d}(n_2, \sigma) \ .
# $$
#
# With the above definitions, we can define the probability density function of a truncated discrete (integer) normal distribution between $n_1$ and $n_2$ as:
#
# $$
# \mathcal{N_{d, t}}(n, n_1, n_2; \sigma) = \frac{\mathcal{N_{d}}(n, \sigma)}{\Phi_{d} (n_1, n_2; \sigma)} \ .
# $$

# %% [markdown]
# # Single vertex random walk
#
# Here I build a version of random walk over LQG intertwiners of a single 4-simplex. Each process runs an independent Markov Chain

# %%
using JupyterFormatter
enable_autoformat()

# %%
using Distributed

# %%
if (nprocs() == 1)
    addprocs(4)
end
println("there are $(nprocs()) processes and $(nworkers()) workers")
# Out:
# there are 5 processes and 4 workers

# %%
@everywhere using HalfIntegers, JLD2, ElasticArrays, Distributions, Random, StatsBase

# %%
@everywhere function random_walk_function(
    j::Float64,
    D::Int64,
    d::Int64,
    A::Array{Float64,5},
    N::Int64,
    b::Int64,
    σ::Float64,
    draws_folder::String,
    chain_id::Int64,
    model::String,
    verbosity::Int64,
)

    draws = ElasticArray{Int64}(undef, 6, 0)     # some allocations    
    ampls = ElasticArray{Float64}(undef, 0)

    Truncated_Coefficients = zeros(Float64, D)    # some allocations   
    Normal_distribution = Normal(0, σ)

    for i = 0:d
        r = 0.0
        for n = (-i):1:(d-i)
            r += (cdf(Normal_distribution, n + 0.5) - cdf(Normal_distribution, n - 0.5))
        end
        Truncated_Coefficients[i+1] = r
    end

    if (myid() == 1)
        if (verbosity > 1)
            println("Truncated coefficients for j=$(j) are $(Truncated_Coefficients)\n")
        end
    end

    #Initial draw and gaussian 
    draw = Array{Int64}(undef, 6)           # some allocations --- # 1 final slot for molteplicity
    gaussian_draw = Array{Int64}(undef, 5)  # some allocations 

    amp = 0.0
    while (amp == 0)
        for i = 1:5
            draw[i] = rand((1:D))     # some allocations        
        end
        amp = A[draw[1], draw[2], draw[3], draw[4], draw[5]]
    end

    draw[6] = 1 # Initial molteplicity      

    if (myid() == 1)
        if (verbosity > 1)
            println("Initial draw is $(draw[1:5]) with amp $(amp)\n")
        end
    end

    #Proposed draw  
    prop_draw = Array{Int64}(undef, 5)      # some allocations

    acceptance_ratio = 0
    molteplicity = 1                              # initial molteplicity counter
    draw_float_sample = Array{Float64}(undef, 1)   # some allocations --- Distribution pkg does not allow it to be scalar without allocating memory     

    RW_monitor = true  # to test if the RW actually moved

    for n = 1:1:N

        RW_monitor = true

        # Sampling proposed draw   
        Cx = Cx_prop = 1.0
        for i = 1:1:5
            while true
                rand!(Normal_distribution, draw_float_sample)
                @inbounds gaussian_draw[i] = round(Int64, draw_float_sample[1])
                @inbounds prop_draw[i] = draw[i] + gaussian_draw[i]
                @inbounds !(1 <= prop_draw[i] && prop_draw[i] <= (D)) || break
            end
            if (gaussian_draw[i] != 0)
                RW_monitor = false
            end
            @inbounds Cx *= Truncated_Coefficients[draw[i]]
            @inbounds Cx_prop *= Truncated_Coefficients[prop_draw[i]]
        end

        if (RW_monitor == true)

            if (myid() == 1)
                if (verbosity > 1)
                    println(
                        "Iteration $(n)---------------------------------------------------------------\n",
                    )
                    println(
                        "The prop_draw below:\n$(prop_draw[1:5])\nturns out to be equal to the current draw:\n$(draw[1:5])\nso that the molteplicity of the current draw is raised to $(molteplicity + 1)\n",
                    )
                end
            end

            acceptance_ratio += 1
            molteplicity += 1
            continue

        else

            if (myid() == 1)
                if (verbosity > 1)
                    println(
                        "Iteration $(n)---------------------------------------------------------------\n",
                    )
                    println(
                        "draw is:\n$(draw[1:5])\nprop_draw is:\n$(prop_draw[1:5])\namp is $(amp)\n",
                    )
                end
            end


            Prop_amp =
                A[prop_draw[1], prop_draw[2], prop_draw[3], prop_draw[4], prop_draw[5]]

            p = min(1.0, (((Prop_amp^2) / (amp^2))) * (Cx / Cx_prop))

            if (isnan(p))
                error(
                    "got NaN while computing densities ratio: prop_draw = $(prop_draw), amp = $(amp)",
                )
            end

            r = rand()

            if (r < p)

                if (myid() == 1)
                    if (verbosity > 1)
                        println(
                            "prop_draw $(prop_draw) was accepted, since p=$(p) and r=$(r)\n",
                        )
                    end
                end

                if (n > b)
                    # TODO avoid resizing at every iteration (pre-allocating assuming >~ 30% accept. rate and re-allocated only at the end) 
                    # and eventually replace matrices with 1-d arrays (more efficient?)
                    resize!(draws, 6, size(draws)[2] + 1)     # some allocations
                    resize!(ampls, size(ampls)[1] + 1)         # some allocations
                    draw[6] = molteplicity
                    draws[:, end] = draw[:]
                    ampls[end] = amp

                    if (myid() == 1)
                        if (verbosity > 1)
                            println(
                                "The old draw $(draw[1:5]) has been stored with molteplicity $(draw[6])\nthe corresponding amplitude $(amp) has been stored as well",
                            )
                        end
                    end

                end

                molteplicity = 1

                for i = 1:5
                    draw[i] = prop_draw[i]
                end

                amp = Prop_amp
                acceptance_ratio += 1

                if (myid() == 1)
                    if (verbosity > 1)
                        println("Now the new draw is $(draw[1:5])\nthe new amp is $(amp)\n")
                    end
                end
            else
                molteplicity += 1
                if (myid() == 1)
                    if (verbosity > 1)
                        println(
                            "prop_draw $(prop_draw) was rejected, since p=$(p) and r=$(r)\nThe current draw $(draw[1:5]) remains the same and its molteplicity is $(molteplicity)\namp remains $(amp)\n",
                        )
                    end
                end
            end # if condition  (r<p)

        end # if condition  RW_monitor == true  

        # final storage  
        if (n == N)
            resize!(draws, 6, size(draws)[2] + 1)     # some allocations 
            resize!(ampls, size(ampls)[1] + 1)         # some allocations 
            draw[6] = molteplicity
            draws[:, end] .= draw[:]
            ampls[end] = amp
            if (myid() == 1)
                if (verbosity > 1)
                    println(
                        "The last draw $(draw[1:5]) has been stored with molteplicity $(draw[6])\n",
                    )
                end
            end
        end

    end # n cycle      

    #This is such that draws has structure: [N,6], so the operators will be computed faster  
    draws = transpose(draws)  # some allocations  

    if (chain_id == 1)
        println(
            "Done! $(acceptance_ratio*100/N)% of proposed draws have been accepted in master chain",
        )
    end

    draws_number = size(draws)[1]

    if (chain_id == 1)
        if (verbosity > 0)
            println("$(draws_number) draws stored in master chain")
        end
    end

    @save "$(draws_folder)/draws_chain=$(chain_id).jld2" draws    # some allocations 
    @save "$(draws_folder)/ampls_chain=$(chain_id).jld2" ampls    # some allocations 

end

# %%
@everywhere begin

    N = 10^6
    b = 0
    σ = 0.9
    draws_folder_base = "../../data/MCMC/draws/N_$(N)_b_$(b)_$(σ)"
    chain_id = myid()
    verbosity = 0

    for model in ["BF", "EPRL"]

        for j = 0.5:0.5:6.0

            local draws_folder = "$(draws_folder_base)/$(model)/j_$(j)"
            mkpath(draws_folder)

            D = Int(2j + 1)
            d = Int(2j)

            @load "../data/$(model)_vertices/julia/vertex_j_$(j).jld2" vertex

            @time random_walk_function(
                j,
                D,
                d,
                vertex,
                N,
                b,
                σ,
                draws_folder,
                chain_id,
                model,
                verbosity,
            )

        end

    end

end
# Out:
# Done! 45.1347% of proposed draws have been accepted in master chain
#   0.738509 seconds (1.98 M allocations: 141.020 MiB, 2.50% gc time, 72.52% compilation time: 100% of which was recompilation)
# Done! 42.1172% of proposed draws have been accepted in master chain
#   0.234227 seconds (369.94 k allocations: 63.570 MiB, 6.41% gc time)
# Done! 34.4567% of proposed draws have been accepted in master chain
#   0.143166 seconds (306.03 k allocations: 56.744 MiB)
# Done! 32.9585% of proposed draws have been accepted in master chain
#   0.144889 seconds (296.95 k allocations: 55.774 MiB)
# Done! 34.7439% of proposed draws have been accepted in master chain
#   0.199346 seconds (318.80 k allocations: 58.108 MiB, 6.35% gc time)
# Done! 34.2371% of proposed draws have been accepted in master chain
#   0.160598 seconds (316.31 k allocations: 57.840 MiB)
# Done! 33.4221% of proposed draws have been accepted in master chain
#   0.229294 seconds (309.69 k allocations: 57.133 MiB, 4.33% gc time)
# Done! 34.7344% of proposed draws have been accepted in master chain
#   0.182478 seconds (324.11 k allocations: 58.674 MiB)
# Done! 34.443% of proposed draws have been accepted in master chain
#   0.153596 seconds (322.30 k allocations: 58.482 MiB)
# Done! 34.3422% of proposed draws have been accepted in master chain
#   0.192517 seconds (321.88 k allocations: 58.436 MiB, 4.30% gc time)
# Done! 34.9805% of proposed draws have been accepted in master chain
#   0.165094 seconds (329.25 k allocations: 59.224 MiB)
# Done! 35.0077% of proposed draws have been accepted in master chain
#   0.214451 seconds (330.24 k allocations: 59.330 MiB, 3.17% gc time)
# Done! 45.1126% of proposed draws have been accepted in master chain
#   0.208496 seconds (348.86 k allocations: 61.319 MiB)
# Done! 41.933% of proposed draws have been accepted in master chain
#   0.174601 seconds (366.77 k allocations: 63.231 MiB)
# Done! 34.9728% of proposed draws have been accepted in master chain
#   0.209599 seconds (309.28 k allocations: 57.091 MiB, 7.50% gc time)
# Done! 32.6977% of proposed draws have been accepted in master chain
#   0.146126 seconds (291.49 k allocations: 55.190 MiB)
# Done! 33.1773% of proposed draws have been accepted in master chain
#   0.154872 seconds (299.47 k allocations: 56.043 MiB, 3.45% gc time)
# Done! 32.6824% of proposed draws have been accepted in master chain
#   0.137846 seconds (296.00 k allocations: 55.672 MiB)
# Done! 32.8313% of proposed draws have been accepted in master chain
#   0.211689 seconds (298.98 k allocations: 55.991 MiB)
# Done! 33.3236% of proposed draws have been accepted in master chain
#   0.223897 seconds (304.74 k allocations: 56.606 MiB, 4.51% gc time)
# Done! 33.6754% of proposed draws have been accepted in master chain
#   0.161033 seconds (308.44 k allocations: 57.002 MiB)
# Done! 33.498% of proposed draws have been accepted in master chain
#   0.182096 seconds (307.06 k allocations: 56.854 MiB, 3.60% gc time)
# Done! 34.6382% of proposed draws have been accepted in master chain
#   0.165619 seconds (320.06 k allocations: 58.243 MiB)
# Done! 34.9516% of proposed draws have been accepted in master chain
#   0.168405 seconds (323.29 k allocations: 58.587 MiB)
#       From worker 5:	  0.726457 seconds (1.99 M allocations: 141.281 MiB, 3.32% gc time, 72.29% compilation time: 100% of which was recompilation)
#       From worker 4:	  0.734864 seconds (1.99 M allocations: 141.396 MiB, 3.50% gc time, 72.84% compilation time: 100% of which was recompilation)
#       From worker 2:	  0.778187 seconds (1.99 M allocations: 141.366 MiB, 3.39% gc time, 72.73% compilation time: 100% of which was recompilation)
#       From worker 3:	  0.749647 seconds (1.99 M allocations: 141.212 MiB, 2.88% gc time, 74.17% compilation time: 100% of which was recompilation)
#       From worker 3:	  0.173581 seconds (370.60 k allocations: 63.644 MiB, 4.88% gc time)
#       From worker 5:	  0.169764 seconds (371.27 k allocations: 63.716 MiB, 7.10% gc time)
#       From worker 5:	  0.154682 seconds (307.95 k allocations: 56.952 MiB, 1.71% gc time)
#       From worker 5:	  0.138438 seconds (297.47 k allocations: 55.834 MiB, 1.14% gc time)
#       From worker 5:	  0.149839 seconds (317.92 k allocations: 58.017 MiB, 0.97% gc time)
#       From worker 5:	  0.222333 seconds (316.02 k allocations: 57.815 MiB, 1.13% gc time)
#       From worker 5:	  0.150428 seconds (311.50 k allocations: 57.332 MiB, 1.38% gc time)
#       From worker 5:	  0.230322 seconds (323.16 k allocations: 58.577 MiB, 1.08% gc time)
#       From worker 5:	  0.136400 seconds (322.21 k allocations: 58.475 MiB, 1.35% gc time)
#       From worker 5:	  0.164949 seconds (320.65 k allocations: 58.309 MiB, 1.28% gc time)
#       From worker 5:	  0.246004 seconds (329.84 k allocations: 59.290 MiB, 0.97% gc time)
#       From worker 5:	  0.199633 seconds (330.92 k allocations: 59.406 MiB, 1.95% gc time)
#       From worker 5:	  0.182146 seconds (349.80 k allocations: 61.423 MiB, 0.83% gc time)
#       From worker 5:	  0.157525 seconds (367.00 k allocations: 63.260 MiB, 2.12% gc time)
#       From worker 5:	  0.212878 seconds (311.53 k allocations: 57.335 MiB, 0.83% gc time)
#       From worker 5:	  0.206569 seconds (289.23 k allocations: 54.953 MiB, 1.13% gc time)
#       From worker 5:	  0.147009 seconds (297.61 k allocations: 55.848 MiB, 1.02% gc time)
#       From worker 5:	  0.141362 seconds (296.33 k allocations: 55.711 MiB, 1.37% gc time)
#       From worker 5:	  0.152705 seconds (299.93 k allocations: 56.096 MiB, 1.28% gc time)
#       From worker 5:	  0.145229 seconds (302.89 k allocations: 56.413 MiB, 1.35% gc time)
#       From worker 4:	  0.199860 seconds (369.32 k allocations: 63.507 MiB, 3.23% gc time)
#       From worker 4:	  0.149545 seconds (306.30 k allocations: 56.776 MiB, 4.68% gc time)
#       From worker 4:	  0.131421 seconds (297.74 k allocations: 55.862 MiB, 0.85% gc time)
#       From worker 4:	  0.135653 seconds (318.65 k allocations: 58.096 MiB, 0.78% gc time)
#       From worker 4:	  0.143665 seconds (316.41 k allocations: 57.856 MiB, 0.87% gc time)
#       From worker 4:	  0.182694 seconds (310.79 k allocations: 57.256 MiB, 1.37% gc time)
#       From worker 4:	  0.156869 seconds (325.67 k allocations: 58.845 MiB, 1.39% gc time)
#       From worker 4:	  0.167291 seconds (321.79 k allocations: 58.431 MiB, 1.04% gc time)
#       From worker 4:	  0.136789 seconds (324.57 k allocations: 58.727 MiB, 1.35% gc time)
#       From worker 4:	  0.217024 seconds (328.66 k allocations: 59.164 MiB, 1.10% gc time)
#       From worker 4:	  0.246020 seconds (330.00 k allocations: 59.308 MiB, 0.97% gc time)
#       From worker 4:	  0.246630 seconds (347.91 k allocations: 61.221 MiB, 0.69% gc time)
#       From worker 4:	  0.156859 seconds (367.20 k allocations: 63.281 MiB, 1.92% gc time)
#       From worker 4:	  0.156431 seconds (312.66 k allocations: 57.456 MiB, 0.87% gc time)
#       From worker 4:	  0.151679 seconds (291.61 k allocations: 55.207 MiB, 1.04% gc time)
#       From worker 4:	  0.153917 seconds (299.78 k allocations: 56.080 MiB, 1.02% gc time)
#       From worker 4:	  0.138238 seconds (295.35 k allocations: 55.606 MiB, 1.06% gc time)
#       From worker 4:	  0.146670 seconds (296.53 k allocations: 55.733 MiB, 0.92% gc time)
#       From worker 4:	  0.145435 seconds (307.92 k allocations: 56.949 MiB, 1.09% gc time)
#       From worker 4:	  0.145744 seconds (306.81 k allocations: 56.831 MiB, 1.00% gc time)
#       From worker 2:	  0.193621 seconds (369.96 k allocations: 63.575 MiB, 5.56% gc time)
#       From worker 2:	  0.214163 seconds (308.25 k allocations: 56.985 MiB, 1.55% gc time)
#       From worker 2:	  0.146622 seconds (296.86 k allocations: 55.768 MiB, 1.31% gc time)
#       From worker 2:	  0.220944 seconds (316.44 k allocations: 57.859 MiB, 1.21% gc time)
#       From worker 2:	  0.151863 seconds (315.55 k allocations: 57.765 MiB, 1.20% gc time)
#       From worker 2:	  0.216444 seconds (310.15 k allocations: 57.188 MiB, 1.21% gc time)
#       From worker 2:	  0.200279 seconds (327.24 k allocations: 59.013 MiB, 0.97% gc time)
#       From worker 2:	  0.157206 seconds (320.32 k allocations: 58.274 MiB, 1.42% gc time)
#       From worker 2:	  0.216933 seconds (321.73 k allocations: 58.424 MiB, 0.98% gc time)
#       From worker 2:	  0.186953 seconds (329.10 k allocations: 59.211 MiB, 0.88% gc time)
#       From worker 2:	  0.222052 seconds (330.12 k allocations: 59.321 MiB, 2.46% gc time)
#       From worker 2:	  0.199391 seconds (348.84 k allocations: 61.320 MiB, 0.61% gc time)
#       From worker 2:	  0.180691 seconds (368.17 k allocations: 63.384 MiB, 1.74% gc time)
#       From worker 2:	  0.182818 seconds (313.81 k allocations: 57.578 MiB, 0.57% gc time)
#       From worker 2:	  0.162855 seconds (290.82 k allocations: 55.122 MiB, 0.97% gc time)
#       From worker 2:	  0.162773 seconds (298.50 k allocations: 55.944 MiB, 1.30% gc time)
#       From worker 2:	  0.166314 seconds (300.06 k allocations: 56.110 MiB, 0.87% gc time)
#       From worker 3:	  0.150704 seconds (306.97 k allocations: 56.848 MiB, 3.68% gc time)
#       From worker 3:	  0.135783 seconds (296.97 k allocations: 55.780 MiB, 1.02% gc time)
#       From worker 3:	  0.139424 seconds (316.61 k allocations: 57.878 MiB, 0.90% gc time)
#       From worker 3:	  0.154442 seconds (315.08 k allocations: 57.715 MiB, 0.84% gc time)
#       From worker 3:	  0.141159 seconds (310.82 k allocations: 57.259 MiB, 1.42% gc time)
#       From worker 3:	  0.161263 seconds (324.94 k allocations: 58.768 MiB, 0.73% gc time)
#       From worker 3:	  0.143236 seconds (321.02 k allocations: 58.348 MiB, 1.27% gc time)
#       From worker 3:	  0.143711 seconds (321.12 k allocations: 58.359 MiB, 1.10% gc time)
#       From worker 3:	  0.175634 seconds (332.46 k allocations: 59.571 MiB, 0.95% gc time)
#       From worker 3:	  0.238659 seconds (331.08 k allocations: 59.423 MiB, 0.97% gc time)
#       From worker 3:	  0.179437 seconds (348.48 k allocations: 61.281 MiB, 0.68% gc time)
#       From worker 3:	  0.157295 seconds (369.47 k allocations: 63.523 MiB, 1.77% gc time)
#       From worker 3:	  0.151981 seconds (312.19 k allocations: 57.405 MiB, 0.80% gc time)
#       From worker 3:	  0.148027 seconds (292.68 k allocations: 55.322 MiB, 1.07% gc time)
#       From worker 3:	  0.144452 seconds (298.35 k allocations: 55.927 MiB, 1.39% gc time)
#       From worker 3:	  0.155888 seconds (299.28 k allocations: 56.027 MiB, 1.74% gc time)
#       From worker 3:	  0.143426 seconds (302.56 k allocations: 56.377 MiB, 1.19% gc time)
#       From worker 3:	  0.149237 seconds (303.64 k allocations: 56.492 MiB, 1.49% gc time)
#       From worker 3:	  0.148868 seconds (310.96 k allocations: 57.274 MiB, 0.97% gc time)
#       From worker 3:	  0.144856 seconds (314.74 k allocations: 57.678 MiB, 1.04% gc time)
#       From worker 2:	  0.157511 seconds (298.96 k allocations: 55.993 MiB, 0.91% gc time)
#       From worker 5:	  0.179730 seconds (308.52 k allocations: 57.013 MiB, 1.08% gc time)
#       From worker 4:	  0.179346 seconds (307.62 k allocations: 56.917 MiB, 0.75% gc time)
#       From worker 3:	  0.141315 seconds (312.91 k allocations: 57.483 MiB, 1.04% gc time)
#       From worker 2:	  0.145638 seconds (304.20 k allocations: 56.552 MiB, 1.26% gc time)
#       From worker 5:	  0.138883 seconds (314.21 k allocations: 57.621 MiB, 1.28% gc time)
#       From worker 4:	  0.141624 seconds (320.40 k allocations: 58.283 MiB, 1.10% gc time)
#       From worker 3:	  0.145093 seconds (326.89 k allocations: 58.976 MiB, 0.98% gc time)
#       From worker 2:	  0.150365 seconds (312.93 k allocations: 57.484 MiB, 0.95% gc time)
#       From worker 5:	  0.139731 seconds (318.44 k allocations: 58.073 MiB, 1.08% gc time)
#       From worker 4:	  0.144626 seconds (322.63 k allocations: 58.521 MiB, 1.03% gc time)
#       From worker 2:	  0.147007 seconds (314.37 k allocations: 57.638 MiB, 1.13% gc time)
#       From worker 5:	  0.148828 seconds (315.68 k allocations: 57.778 MiB, 1.08% gc time)
#       From worker 2:	  0.149853 seconds (313.50 k allocations: 57.545 MiB, 0.99% gc time)
#       From worker 2:	  0.157695 seconds (313.54 k allocations: 57.550 MiB, 1.14% gc time)

# %% [markdown]
# # Computing dihedral angles
#
# Let's compute the expectation value of the dihedral angle on the first node

# %%
function from_intertwiner_to_angle(i::Int64, j)
    return (i * (i + 1) - 2j * (j + 1)) / (2j * (j + 1))
end
# Out:
# from_intertwiner_to_angle (generic function with 1 method)

# %%
# not optimized

function angles_computation!(
    chains_to_assemble::Int64,
    angle_all_chains,
    angle_numerical_fluctuations,
    model::String,
    j::Float64,
    N,
    b,
    draws_folder::String,
)

    for chain_id = 1:chains_to_assemble

        @load "$(draws_folder)/ampls_chain=$(chain_id).jld2" ampls
        @load "$(draws_folder)/draws_chain=$(chain_id).jld2" draws
        number_of_elements_in_this_chain = size(ampls)[1]

        angle_this_chain = 0.0

        for i = 1:number_of_elements_in_this_chain
            angle_this_chain += from_intertwiner_to_angle(draws[i, 1] - 1, j) * draws[i, 6]
        end

        angle_this_chain /= (N - b)
        angle_all_chains[chain_id] = angle_this_chain

        # average_angle_first_node 
        angle_numerical_fluctuations[1] = mean(angle_all_chains[:])

        # std_dev_angle_first_node 
        angle_numerical_fluctuations[2] = std(angle_all_chains[:])

        # number of combined chains
        angle_numerical_fluctuations[3] = chains_to_assemble

    end

end
# Out:
# angles_computation! (generic function with 1 method)

# %%
using CSV, DataFrames

# %%
chains_to_assemble = nprocs()

N = 10^6
b = 0
σ = 0.9
draws_folder_base = "../data/MCMC/draws/N_$(N)_b_$(b)_$(σ)"
operator_folder_base = "../data/MCMC/operators/N_$(N)_b_$(b)_$(σ)"

for model in ["BF", "EPRL"]

    chain_id = myid()

    angle_fluctuations_table = DataFrame()

    # creating first column of angles numerical fluctuations dataframe 
    array = String[]
    push!(array, "avg. angles (first node)")
    push!(array, "std. angles (first node)")
    push!(array, "n. chains combined")

    angle_fluctuations_table = DataFrame(numerical_data = array)

    angle_all_chains = zeros(Float64, chains_to_assemble)
    angle_numerical_fluctuations = zeros(Float64, 3)

    for j = 0.5:0.5:6.0

        local draws_folder = "$(draws_folder_base)/$(model)/j_$(j)"

        column_name = "j=$(j)"

        # not optimized
        @time angles_computation!(
            chains_to_assemble,
            angle_all_chains,
            angle_numerical_fluctuations,
            model,
            j,
            N,
            b,
            draws_folder,
        )

        angle_numerical_fluctuations_dataframe =
            DataFrame(to_rename = angle_numerical_fluctuations)
        rename!(angle_numerical_fluctuations_dataframe, :to_rename => column_name)

        angle_fluctuations_table =
            hcat(angle_fluctuations_table, angle_numerical_fluctuations_dataframe)

    end

    local operator_folder = "$(operator_folder_base)/$(model)"
    mkpath(operator_folder)

    CSV.write(
        "$(operator_folder)/angles_numerical_fluctuations_table.csv",
        angle_fluctuations_table,
    )

end
# Out:
#   0.262609 seconds (10.40 M allocations: 278.984 MiB, 6.70% gc time)
#   0.278696 seconds (11.07 M allocations: 296.924 MiB, 7.15% gc time)
#   0.241452 seconds (9.18 M allocations: 246.362 MiB, 8.66% gc time)
#   0.217957 seconds (8.88 M allocations: 238.432 MiB, 4.49% gc time)
#   0.246234 seconds (9.50 M allocations: 254.841 MiB, 8.38% gc time)
#   0.242434 seconds (9.44 M allocations: 253.386 MiB, 7.68% gc time)
#   0.230148 seconds (9.28 M allocations: 249.154 MiB, 4.20% gc time)
#   0.247473 seconds (9.72 M allocations: 260.720 MiB, 9.01% gc time)
#   0.246514 seconds (9.61 M allocations: 257.920 MiB, 7.82% gc time)
#   0.241779 seconds (9.63 M allocations: 258.288 MiB, 4.93% gc time)
#   0.262808 seconds (9.86 M allocations: 264.595 MiB, 8.09% gc time)
#   0.261526 seconds (9.88 M allocations: 265.087 MiB, 8.55% gc time)
#   0.268311 seconds (10.43 M allocations: 279.750 MiB, 4.49% gc time)
#   0.286276 seconds (11.00 M allocations: 294.924 MiB, 8.95% gc time)
#   0.241538 seconds (9.32 M allocations: 250.202 MiB, 7.94% gc time)
#   0.224304 seconds (8.70 M allocations: 233.597 MiB, 8.61% gc time)
#   0.217811 seconds (8.93 M allocations: 239.669 MiB, 4.28% gc time)
#   0.241661 seconds (8.89 M allocations: 238.596 MiB, 9.59% gc time)
#   0.227923 seconds (8.95 M allocations: 240.191 MiB, 4.37% gc time)
#   0.239983 seconds (9.11 M allocations: 244.424 MiB, 8.04% gc time)
#   0.247170 seconds (9.25 M allocations: 248.314 MiB, 8.63% gc time)
#   0.235131 seconds (9.31 M allocations: 249.969 MiB, 4.45% gc time)
#   0.247865 seconds (9.48 M allocations: 254.345 MiB, 7.79% gc time)
#   0.250755 seconds (9.58 M allocations: 257.024 MiB, 8.32% gc time)
