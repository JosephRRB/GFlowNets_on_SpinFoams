# %% [markdown]
# # Markov Chain Monte Carlo (MCMC)

# %% [markdown]
# Let's consider a quantity $O$ which can be computed as:
#
# $$
# O = \sum\limits_{x \in \chi} o \left( x \right) \tilde{f} \left( x \right) \ ,
# $$
#
# where $x$ is a (possibly multidimensional) discrete variable on a state space $\chi$ which must be summed over, while $\tilde{f}$ is a probability density function on $\chi$, so that $\sum\limits_{x \in \chi} \tilde{f} \left( x \right) = 1$. From now on, we define $\tilde{f}$ as the $\textbf{target}$ distribution and we omit the state space label $\chi$. Since the target distribution is normalized, we can write:
#
# $$
# \tilde{f} \left( x \right) \equiv \frac{f \left( x \right)}{\sum\limits_{x} f \left( x \right)} \ ,
# $$
#
# from which:
#
# $$
# O = \frac{ \sum\limits_{x} f \left( x \right) o \left( x \right) }{\sum\limits_{x} f \left( x \right)} \ .
# $$
#
# If the target distribution is computable up to a multiplying constant, the $\textbf{Metropolis–Hastings algorithm}$ allows to construct on state space $\chi$ an ergodic Markov chain with length $N_{MC}$: $x_{1} , \ x_{2} , \ x_{3} \dots , x_{n} \ \dots , x_{N_{MC}}$ such that $x_{n}$ is converging (in distribution) to $\tilde{f}$, exploring the space $\chi$ progressively. If we define:
#
# $$
# O_{N_{MC}} = \frac{1}{N_{MC}} \sum\limits_{i = 1}^{N_{MC}} o \left(x_i \right) \ ,
# $$
#
# then, since the chain can be considered as a statistical sample, the law of large numbers ensures that:
#
# $$
# \lim_{N_{MC} \to \infty} O_{N_{MC}}  = O \ ,
# $$
#
# which allows us to write:
#
# $$
# O_{N_{MC}} \approx O \hspace{3mm} \textrm{for $N_{MC} \gg 1$} \ .
# $$
#
# Namely, we end up with an estimate of the original sum. Since the simulation is Markovian and the chain itself can be considered as a statistical sample, the latter usually depends on the starting value. The initial steps are tipically removed as $\textbf{burn-in}$, when the chain is still in the so-called $\textbf{thermalization}$ phase.
#
# In order to transit from the value $x_{n}$ of the chain to the value $x_{n + 1}$, we require a $\textbf{proposal distribution}$ $q$ defined on space $\chi$. If $q$ is positive everywhere, then the Metropolis-Hastings algorithm preserves $\tilde{f}$ as the stationary distribution to which the chain is progressively converging.
#
# In the $\textbf{random walk Metropolis-Hastings}$, the proposal distribution consists in a local exploration of the neighborhood of the current value $x_n$ of the
# Markov chain. That is, the proposed value $y_n$ is simulated as:
#
# $$
# y_n = x_n + \epsilon_n \ ,
# $$
#
# where $\epsilon_n$ is a random perturbation with distribution $g$. As proposal distribution $g$, we focus on a discrete truncated normal distribution centered on $x_n$. A few relevant definitions are discussed next.
#
# Finally, since $x_n$ depends on the previous element along the Markov chain, this induces a non-zero correlation between $x_n$ and $x_{n+d}$. The correlation between $x_n$ and $x_{n+d}$ is defined as the $\textbf{autocorrelation}$ at lag $d$. For a Markov chain that converges to a stationary distribution, the autocorrelation should indeed decrease as the lag increases. The definition of the autocorrelation function between the chain elements $x_n$ and $x_{n+d}$ is defined as the expected value $\mathbb{E} \left(x_n x_{n+d} \right) $.
#
# ### Truncated normal distribution
#
# The probability density function of a normal distribution with mean $0$ and standard deviation $\sigma$ is defined as:
#
# $$
# \mathcal{N}(x, \sigma) = \frac{1}{\sigma \sqrt{2 \pi}}e^{-\frac{x^2}{2 \sigma^2}} \ ,
# $$
#
# where $x \in \mathbb{R}$. The probability density function of a normal distribution with mean $\mu$ is simply given by $\mathcal{N}(x - \mu, \sigma)$ .
#
#
# In the discrete (integer) case, we can define the probability density function of a normal distribution with mean $0$ and standard deviation $\sigma$ as:
#
# $$
# \mathcal{N}_{d}(n, \sigma) = \Phi ( n + 0.5, \sigma ) - \Phi (n - 0.5, \sigma ) \ ,
# $$
#
# where $n \in \mathbb{N}$ and $\Phi ( x, \sigma ) $ is the cumulative distribution function of a normal distribution with mean $0$ and standard deviation $\sigma$, defined as:
#
# $$
# \Phi (x , \sigma) = \frac{1}{\sigma \sqrt{2 \pi}} \int_{- \infty}^{x} e^{-\frac{t^2}{2 \sigma^2}} dt \ .
# $$
#
# For convenience, let's also define:
#
# $$
# \Phi (a, b; \sigma) = \Phi (b, \sigma) - \Phi (a, \sigma) = \frac{1}{\sigma \sqrt{2 \pi}} \int_{a}^{b} e^{-\frac{t^2}{2 \sigma^2}} dt \ .
# $$
#
# The cumulative distribution function of a discrete (integer) gaussian is written as:
#
# $$
# \Phi_{d} (n_1, n_2; \sigma) = \mathcal{N}_{d}(n_1, \sigma) + \mathcal{N}_{d}(n_1 + 1, \sigma) + \dots + \mathcal{N}_{d}(n_2, \sigma) \ .
# $$
#
# With the above definitions, we can define the probability density function of a truncated discrete (integer) normal distribution between $n_1$ and $n_2$ as:
#
# $$
# \mathcal{N_{d, t}}(n, n_1, n_2; \sigma) = \frac{\mathcal{N_{d}}(n, \sigma)}{\Phi_{d} (n_1, n_2; \sigma)} \ .
# $$

# %% [markdown]
# # Single vertex random walk
#
# Here I build a version of random walk over LQG intertwiners of a single 4-simplex.

# %%
using JupyterFormatter
enable_autoformat()
# Out:
# 1-element Vector{Function}:
#  format_current_cell (generic function with 1 method)

# %%
#using Distributed

# %%
#if (nprocs() == 1)
#    addprocs(4)
#end
#println("there are $(nprocs()) processes and $(nworkers()) workers")

# %%
using HalfIntegers,
    JLD2, ElasticArrays, Distributions, Random, StatsBase, DataFrames, CSV, Dates

# %%
function VertexMCMC(
    j::Float64,
    D::Int64,
    A::Array{Float64,5},
    N::Int64,
    batch_size::Int64,
    b::Int64,
    σ::Float64,
    draws_folder::String,
    verbosity::Int64,
)

    if (N % batch_size != 0)
        error("Number of iterations must be a multiple of batch size ")
    end

    draws = ElasticArray{Int64}(undef, 6, 0)
    Truncated_Coefficients = zeros(Float64, D)
    Normal_distribution = Normal(0, σ)

    d = D - 1

    for i = 0:d
        r = 0.0
        for n = (-i):1:(d-i)
            r += (cdf(Normal_distribution, n + 0.5) - cdf(Normal_distribution, n - 0.5))
        end
        Truncated_Coefficients[i+1] = r
    end

    if (verbosity > 1)
        println("\nTruncated coefficients for j=$(j) are $(Truncated_Coefficients)\n")
    end

    # Initial draw and gaussian 
    draw = Array{Int64}(undef, 6)           # 1 final slot for multiplicity
    gaussian_draw = Array{Int64}(undef, 5)

    amp = 0.0
    while (amp == 0)
        for i = 1:5
            draw[i] = rand((1:D))
        end
        amp = A[draw[1], draw[2], draw[3], draw[4], draw[5]]
    end

    draw[6] = 1 # Initial multiplicity      

    if (verbosity > 1)
        println("Initial draw is $(draw[1:5]) with amp $(amp)\n")
    end

    # Proposed draw  
    prop_draw = Array{Int64}(undef, 5)

    acceptance_ratio = 0
    multiplicity = 1                              # initial multiplicity counter
    draw_float_sample = Array{Float64}(undef, 1)   # some allocations --- Distribution pkg does not allow it to be scalar without allocating memory     

    RW_monitor = true  # to test if the RW actually moved

    df_all_batches = DataFrame([[], []], ["acceptance rate (%)", "run time (s)"])
    batch_counter = 0

    for n = 1:1:N

        if (verbosity > 1)
            println(
                "Iteration $(n)---------------------------------------------------------------\n",
            )
        end

        T_in = time_ns()

        if (n % batch_size == 0)

            if (verbosity > 1)
                println("$(n) iterations reached, time to store $(batch_size) draws\n")
            end

            resize!(draws, 6, size(draws)[2] + 1)
            #draw[6] = multiplicity
            draws[1:5, end] .= draw[1:5] .- 1
            draws[6, end] = multiplicity

            if (verbosity > 1)
                println(
                    "The last draw $(draw[1:5]) has been stored with multiplicity $(draw[6])\n",
                )
            end

            acceptance_percentage = acceptance_ratio * 100 / batch_size

            println(
                "$(acceptance_percentage)% of proposed draws have been accepted in this batch (in master chain)\n",
            )

            batch_counter += 1

            CSV.write(
                "$(draws_folder)/draws_batch_n_$(batch_counter).csv",
                DataFrame(
                    transpose(draws),
                    [
                        "intertwiner 1",
                        "intertwiner 2",
                        "intertwiner 3",
                        "intertwiner 4",
                        "intertwiner 5",
                        "multiplicity",
                    ],
                ),
            )

            T_fin = time_ns()

            push!(
                df_all_batches,
                [acceptance_percentage, round((T_fin - T_in) * 10^(-9), digits = 4)],
            )

            acceptance_ratio = 0
            multiplicity = 1
            resize!(draws, 6, 0)

            if (n == N)
                CSV.write("$(draws_folder)/statistics_batches.csv", df_all_batches)
            end

            continue

        end

        RW_monitor = true

        # Sampling proposed draw   
        Cx = Cx_prop = 1.0
        for i = 1:1:5
            while true
                rand!(Normal_distribution, draw_float_sample)
                @inbounds gaussian_draw[i] = round(Int64, draw_float_sample[1])
                @inbounds prop_draw[i] = draw[i] + gaussian_draw[i]
                @inbounds !(1 <= prop_draw[i] && prop_draw[i] <= (D)) || break
            end
            if (gaussian_draw[i] != 0)
                RW_monitor = false
            end
            @inbounds Cx *= Truncated_Coefficients[draw[i]]
            @inbounds Cx_prop *= Truncated_Coefficients[prop_draw[i]]
        end

        if (RW_monitor == true)

            if (verbosity > 1)
                println(
                    "The prop_draw below:\n$(prop_draw[1:5])\nturns out to be equal to the current draw:\n$(draw[1:5])\nso that the multiplicity of the current draw is raised to $(multiplicity + 1)\n",
                )
            end

            acceptance_ratio += 1
            multiplicity += 1

            continue

        else

            if (verbosity > 1)
                println(
                    "draw is:\n$(draw[1:5])\nprop_draw is:\n$(prop_draw[1:5])\namp is $(amp)\n",
                )
            end


            Prop_amp =
                A[prop_draw[1], prop_draw[2], prop_draw[3], prop_draw[4], prop_draw[5]]

            p = min(1.0, (((Prop_amp^2) / (amp^2))) * (Cx / Cx_prop))

            if (isnan(p))
                error(
                    "got NaN while computing densities ratio: prop_draw = $(prop_draw), amp = $(amp)",
                )
            end

            r = rand()

            if (r < p)

                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was accepted, since p=$(p) and r=$(r)\n",
                    )
                end

                if (n > b)

                    resize!(draws, 6, size(draws)[2] + 1)
                    #draw[6] = multiplicity
                    draws[1:5, end] .= draw[1:5] .- 1
                    draws[6, end] = multiplicity

                    if (verbosity > 1)
                        println(
                            "The old draw $(draw[1:5]) has been stored with multiplicity $(draw[6])\n",
                        )
                    end

                end

                multiplicity = 1

                for i = 1:5
                    draw[i] = prop_draw[i]
                end

                amp = Prop_amp
                acceptance_ratio += 1

                if (verbosity > 1)
                    println("Now the new draw is $(draw[1:5])\nthe new amp is $(amp)\n")
                end
            else
                multiplicity += 1
                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was rejected, since p=$(p) and r=$(r)\nThe current draw $(draw[1:5]) remains the same and its multiplicity is $(multiplicity)\namp remains $(amp)\n",
                    )
                end
            end

        end

    end

end
# Out:
# VertexMCMC (generic function with 1 method)

# %%
N = 10^7
batch_size = 10^6
b = 0
σ = 0.8
draws_folder_base = "../../data/MCMC/vertex/iterations_$(N)_batch_size_$(batch_size)_burnin_$(b)_sigma_$(σ)"
verbosity = 0

for j = 0.5:0.5:6.0

    local draws_folder = "$(draws_folder_base)/j_$(j)/draws"
    mkpath(draws_folder)

    D = Int(2j + 1)
    @load "../../data/EPRL_vertices/Julia/Dl_20/vertex_j_$(j).jld2" vertex
    @time VertexMCMC(j, D, vertex, N, batch_size, b, σ, draws_folder, verbosity)

end
# Out:
# 46.3309% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2533% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2526% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2304% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2556% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2495% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2282% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2753% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2937% of proposed draws have been accepted in this batch (in master chain)
#
# 46.2977% of proposed draws have been accepted in this batch (in master chain)
#
#   3.830502 seconds (87.08 M allocations: 2.669 GiB, 4.93% gc time, 5.22% compilation time)
# 43.9734% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8189% of proposed draws have been accepted in this batch (in master chain)
#
# 43.9902% of proposed draws have been accepted in this batch (in master chain)
#
# 43.9689% of proposed draws have been accepted in this batch (in master chain)
#
# 43.6136% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8197% of proposed draws have been accepted in this batch (in master chain)
#
# 43.851% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8243% of proposed draws have been accepted in this batch (in master chain)
#
# 43.8245% of proposed draws have been accepted in this batch (in master chain)
#
# 43.7256% of proposed draws have been accepted in this batch (in master chain)
#
#   3.731556 seconds (93.95 M allocations: 2.862 GiB, 4.83% gc time)
# 38.3033% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3863% of proposed draws have been accepted in this batch (in master chain)
#
# 38.1054% of proposed draws have been accepted in this batch (in master chain)
#
# 38.5062% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3453% of proposed draws have been accepted in this batch (in master chain)
#
# 38.5256% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3547% of proposed draws have been accepted in this batch (in master chain)
#
# 38.2784% of proposed draws have been accepted in this batch (in master chain)
#
# 38.2514% of proposed draws have been accepted in this batch (in master chain)
#
# 38.0335% of proposed draws have been accepted in this batch (in master chain)
#
#   3.450171 seconds (83.26 M allocations: 2.543 GiB, 4.84% gc time)
# 35.8996% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0318% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0736% of proposed draws have been accepted in this batch (in master chain)
#
# 35.9958% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0577% of proposed draws have been accepted in this batch (in master chain)
#
# 35.6026% of proposed draws have been accepted in this batch (in master chain)
#
# 35.7499% of proposed draws have been accepted in this batch (in master chain)
#
# 35.8937% of proposed draws have been accepted in this batch (in master chain)
#
# 35.8475% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0577% of proposed draws have been accepted in this batch (in master chain)
#
#   3.379815 seconds (78.71 M allocations: 2.408 GiB, 4.98% gc time)
# 36.4003% of proposed draws have been accepted in this batch (in master chain)
#
# 35.8066% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2266% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2359% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0058% of proposed draws have been accepted in this batch (in master chain)
#
# 36.1145% of proposed draws have been accepted in this batch (in master chain)
#
# 36.5048% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4988% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0604% of proposed draws have been accepted in this batch (in master chain)
#
# 36.075% of proposed draws have been accepted in this batch (in master chain)
#
#   3.488643 seconds (80.35 M allocations: 2.457 GiB, 9.04% gc time)
# 36.0677% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4965% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2087% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2602% of proposed draws have been accepted in this batch (in master chain)
#
# 36.3725% of proposed draws have been accepted in this batch (in master chain)
#
# 36.1569% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4705% of proposed draws have been accepted in this batch (in master chain)
#
# 36.2001% of proposed draws have been accepted in this batch (in master chain)
#
# 36.3761% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0426% of proposed draws have been accepted in this batch (in master chain)
#
#   3.178458 seconds (81.19 M allocations: 2.482 GiB, 4.76% gc time)
# 36.4016% of proposed draws have been accepted in this batch (in master chain)
#
# 36.5796% of proposed draws have been accepted in this batch (in master chain)
#
# 36.6843% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0935% of proposed draws have been accepted in this batch (in master chain)
#
# 36.8812% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4161% of proposed draws have been accepted in this batch (in master chain)
#
# 36.076% of proposed draws have been accepted in this batch (in master chain)
#
# 36.5445% of proposed draws have been accepted in this batch (in master chain)
#
# 36.7303% of proposed draws have been accepted in this batch (in master chain)
#
# 36.7149% of proposed draws have been accepted in this batch (in master chain)
#
#   3.201914 seconds (82.29 M allocations: 2.514 GiB, 4.85% gc time)
# 37.0898% of proposed draws have been accepted in this batch (in master chain)
#
# 36.0376% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4817% of proposed draws have been accepted in this batch (in master chain)
#
# 37.0446% of proposed draws have been accepted in this batch (in master chain)
#
# 36.6292% of proposed draws have been accepted in this batch (in master chain)
#
# 36.4114% of proposed draws have been accepted in this batch (in master chain)
#
# 36.5343% of proposed draws have been accepted in this batch (in master chain)
#
# 36.938% of proposed draws have been accepted in this batch (in master chain)
#
# 36.3574% of proposed draws have been accepted in this batch (in master chain)
#
# 37.1493% of proposed draws have been accepted in this batch (in master chain)
#
#   3.338245 seconds (82.86 M allocations: 2.531 GiB, 5.05% gc time)
# 37.4426% of proposed draws have been accepted in this batch (in master chain)
#
# 37.2171% of proposed draws have been accepted in this batch (in master chain)
#
# 36.7491% of proposed draws have been accepted in this batch (in master chain)
#
# 37.6683% of proposed draws have been accepted in this batch (in master chain)
#
# 37.8419% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5998% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5932% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5458% of proposed draws have been accepted in this batch (in master chain)
#
# 37.4157% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5826% of proposed draws have been accepted in this batch (in master chain)
#
#   3.316005 seconds (85.35 M allocations: 2.606 GiB, 4.67% gc time)
# 38.1825% of proposed draws have been accepted in this batch (in master chain)
#
# 37.9964% of proposed draws have been accepted in this batch (in master chain)
#
# 37.728% of proposed draws have been accepted in this batch (in master chain)
#
# 37.4398% of proposed draws have been accepted in this batch (in master chain)
#
# 37.3383% of proposed draws have been accepted in this batch (in master chain)
#
# 37.9383% of proposed draws have been accepted in this batch (in master chain)
#
# 37.9724% of proposed draws have been accepted in this batch (in master chain)
#
# 37.3604% of proposed draws have been accepted in this batch (in master chain)
#
# 37.7587% of proposed draws have been accepted in this batch (in master chain)
#
# 37.2617% of proposed draws have been accepted in this batch (in master chain)
#
#   3.442670 seconds (86.09 M allocations: 2.628 GiB, 5.19% gc time)
# 38.6294% of proposed draws have been accepted in this batch (in master chain)
#
# 37.9123% of proposed draws have been accepted in this batch (in master chain)
#
# 37.5048% of proposed draws have been accepted in this batch (in master chain)
#
# 37.3013% of proposed draws have been accepted in this batch (in master chain)
#
# 38.4221% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3887% of proposed draws have been accepted in this batch (in master chain)
#
# 37.4646% of proposed draws have been accepted in this batch (in master chain)
#
# 38.6491% of proposed draws have been accepted in this batch (in master chain)
#
# 38.4309% of proposed draws have been accepted in this batch (in master chain)
#
# 38.495% of proposed draws have been accepted in this batch (in master chain)
#
#   3.417838 seconds (87.32 M allocations: 2.665 GiB, 4.73% gc time)
# 39.2954% of proposed draws have been accepted in this batch (in master chain)
#
# 38.6192% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3251% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3607% of proposed draws have been accepted in this batch (in master chain)
#
# 37.2044% of proposed draws have been accepted in this batch (in master chain)
#
# 38.4543% of proposed draws have been accepted in this batch (in master chain)
#
# 38.3446% of proposed draws have been accepted in this batch (in master chain)
#
# 39.1717% of proposed draws have been accepted in this batch (in master chain)
#
# 38.736% of proposed draws have been accepted in this batch (in master chain)
#
# 38.9172% of proposed draws have been accepted in this batch (in master chain)
#
#   3.460959 seconds (88.57 M allocations: 2.702 GiB, 4.76% gc time)

# %% [markdown]
# # Star random walk
#
# Here I build a version of random walk over LQG intertwiners of the star model.

# %%
using LoopVectorization

# %%
# computes star amplitude for given dimensions, vertex amplitude, containers for contraction and indices
function star_amplitude(D, A, v1, v2, v3, v4, v5, indices)

    @turbo for i = 1:D

        v1[i] = A[i, indices[1], indices[2], indices[3], indices[4]]
        v2[i] = A[i, indices[5], indices[6], indices[7], indices[8]]
        v3[i] = A[i, indices[9], indices[10], indices[11], indices[12]]
        v4[i] = A[i, indices[13], indices[14], indices[15], indices[16]]
        v5[i] = A[i, indices[17], indices[18], indices[19], indices[20]]

    end

    s = 0.0

    @turbo for q = 1:D, l = 1:D, k = 1:D, j = 1:D, m = 1:D
        s += A[m, j, k, l, q] * v1[q] * v2[l] * v3[k] * v4[j] * v5[m]
    end
    return s

end
# Out:
# star_amplitude (generic function with 1 method)

# %%
function StarMCMC(
    j::Float64,
    D::Int64,
    A::Array{Float64,5},
    N::Int64,
    batch_size::Int64,
    b::Int64,
    σ::Float64,
    draws_folder::String,
    verbosity::Int64,
)

    # containers for contraction
    v1 = zeros(Float64, D)
    v2 = zeros(Float64, D)
    v3 = zeros(Float64, D)
    v4 = zeros(Float64, D)
    v5 = zeros(Float64, D)

    if (N % batch_size != 0)
        error("Number of iterations must be a multiple of batch size ")
    end

    draws = ElasticArray{Int64}(undef, 21, 0)
    Truncated_Coefficients = zeros(Float64, D)
    Normal_distribution = Normal(0, σ)

    d = D - 1

    for i = 0:d
        r = 0.0
        for n = (-i):1:(d-i)
            r += (cdf(Normal_distribution, n + 0.5) - cdf(Normal_distribution, n - 0.5))
        end
        Truncated_Coefficients[i+1] = r
    end

    if (verbosity > 1)
        println("\nTruncated coefficients for j=$(j) are $(Truncated_Coefficients)\n")
    end

    # Initial draw and gaussian 
    draw = Array{Int64}(undef, 21)           # 1 final slot for multiplicity
    gaussian_draw = Array{Int64}(undef, 20)

    amp = 0.0
    while (amp == 0)
        for i = 1:20
            draw[i] = rand((1:D))
        end
        amp = star_amplitude(D, A, v1, v2, v3, v4, v5, draw)
    end

    draw[6] = 1 # Initial multiplicity      

    if (verbosity > 1)
        println("Initial draw is $(draw[1:20]) with amp $(amp)\n")
    end

    # Proposed draw  
    prop_draw = Array{Int64}(undef, 20)

    acceptance_ratio = 0
    multiplicity = 1                              # initial multiplicity counter
    draw_float_sample = Array{Float64}(undef, 1)   # some allocations --- Distribution pkg does not allow it to be scalar without allocating memory     

    RW_monitor = true  # to test if the RW actually moved

    df_all_batches = DataFrame([[], []], ["acceptance rate (%)", "run time (s)"])
    batch_counter = 0

    for n = 1:1:N

        if (verbosity > 1)
            println(
                "Iteration $(n)---------------------------------------------------------------\n",
            )
        end

        T_in = time_ns()

        if (n % batch_size == 0)

            if (verbosity > 1)
                println("$(n) iterations reached, time to store $(batch_size) draws\n")
            end

            resize!(draws, 21, size(draws)[2] + 1)

            draws[1:20, end] .= draw[1:20] .- 1
            draws[21, end] = multiplicity

            if (verbosity > 1)
                println(
                    "The last draw $(draw[1:20]) has been stored with multiplicity $(draw[6])\n",
                )
            end

            acceptance_percentage = acceptance_ratio * 100 / batch_size

            println(
                "$(acceptance_percentage)% of proposed draws have been accepted in this batch (in master chain)\n",
            )

            batch_counter += 1

            CSV.write(
                "$(draws_folder)/draws_batch_n_$(batch_counter).csv",
                DataFrame(
                    transpose(draws),
                    [
                        "intertwiner 1",
                        "intertwiner 2",
                        "intertwiner 3",
                        "intertwiner 4",
                        "intertwiner 5",
                        "intertwiner 6",
                        "intertwiner 7",
                        "intertwiner 8",
                        "intertwiner 9",
                        "intertwiner 10",
                        "intertwiner 11",
                        "intertwiner 12",
                        "intertwiner 13",
                        "intertwiner 14",
                        "intertwiner 15",
                        "intertwiner 16",
                        "intertwiner 17",
                        "intertwiner 18",
                        "intertwiner 19",
                        "intertwiner 20",
                        "multiplicity",
                    ],
                ),
            )

            T_fin = time_ns()

            push!(
                df_all_batches,
                [acceptance_percentage, round((T_fin - T_in) * 10^(-9), digits = 4)],
            )

            acceptance_ratio = 0
            multiplicity = 1
            resize!(draws, 21, 0)

            if (n == N)
                CSV.write("$(draws_folder)/statistics_batches.csv", df_all_batches)
            end

            continue

        end

        RW_monitor = true

        # Sampling proposed draw   
        Cx = Cx_prop = 1.0
        for i = 1:20
            while true
                rand!(Normal_distribution, draw_float_sample)
                @inbounds gaussian_draw[i] = round(Int64, draw_float_sample[1])
                @inbounds prop_draw[i] = draw[i] + gaussian_draw[i]
                @inbounds !(1 <= prop_draw[i] && prop_draw[i] <= (D)) || break
            end
            if (gaussian_draw[i] != 0)
                RW_monitor = false
            end
            @inbounds Cx *= Truncated_Coefficients[draw[i]]
            @inbounds Cx_prop *= Truncated_Coefficients[prop_draw[i]]
        end

        if (RW_monitor == true)

            if (verbosity > 1)
                println(
                    "The prop_draw below:\n$(prop_draw[1:20])\nturns out to be equal to the current draw:\n$(draw[1:20])\nso that the multiplicity of the current draw is raised to $(multiplicity + 1)\n",
                )
            end

            acceptance_ratio += 1
            multiplicity += 1

            continue

        else

            if (verbosity > 1)
                println(
                    "draw is:\n$(draw[1:20])\nprop_draw is:\n$(prop_draw[1:20])\namp is $(amp)\n",
                )
            end


            Prop_amp = star_amplitude(D, A, v1, v2, v3, v4, v5, prop_draw)

            p = min(1.0, (((Prop_amp^2) / (amp^2))) * (Cx / Cx_prop))

            if (isnan(p))
                error(
                    "got NaN while computing densities ratio: prop_draw = $(prop_draw), amp = $(amp)",
                )
            end

            r = rand()

            if (r < p)

                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was accepted, since p=$(p) and r=$(r)\n",
                    )
                end

                if (n > b)

                    resize!(draws, 21, size(draws)[2] + 1)

                    draws[1:20, end] .= draw[1:20] .- 1
                    draws[21, end] = multiplicity

                    if (verbosity > 1)
                        println(
                            "The old draw $(draw[1:20]) has been stored with multiplicity $(draw[21])\n",
                        )
                    end

                end

                multiplicity = 1

                for i = 1:20
                    draw[i] = prop_draw[i]
                end

                amp = Prop_amp
                acceptance_ratio += 1

                if (verbosity > 1)
                    println("Now the new draw is $(draw[1:20])\nthe new amp is $(amp)\n")
                end
            else
                multiplicity += 1
                if (verbosity > 1)
                    println(
                        "prop_draw $(prop_draw) was rejected, since p=$(p) and r=$(r)\nThe current draw $(draw[1:20]) remains the same and its multiplicity is $(multiplicity)\namp remains $(amp)\n",
                    )
                end
            end

        end

    end

end
# Out:
# StarMCMC (generic function with 1 method)

# %%
N = 10^6
batch_size = 10^5
b = 0
σ = 0.4
draws_folder_base = "../../data/MCMC/star/iterations_$(N)_batch_size_$(batch_size)_burnin_$(b)_sigma_$(σ)"
verbosity = 0

for j = 0.5:0.5:6.0

    local draws_folder = "$(draws_folder_base)/j_$(j)/draws"
    mkpath(draws_folder)

    D = Int(2j + 1)
    @load "../../data/EPRL_vertices/Julia/Dl_20/vertex_j_$(j).jld2" vertex
    @time StarMCMC(j, D, vertex, N, batch_size, b, σ, draws_folder, verbosity)

end
# Out:
# 29.025% of proposed draws have been accepted in this batch (in master chain)
#
# 28.898% of proposed draws have been accepted in this batch (in master chain)
#
# 28.617% of proposed draws have been accepted in this batch (in master chain)
#
# 29.009% of proposed draws have been accepted in this batch (in master chain)
#
# 28.425% of proposed draws have been accepted in this batch (in master chain)
#
# 28.686% of proposed draws have been accepted in this batch (in master chain)
#
# 28.981% of proposed draws have been accepted in this batch (in master chain)
#
# 28.989% of proposed draws have been accepted in this batch (in master chain)
#
# 28.693% of proposed draws have been accepted in this batch (in master chain)
#
# 29.011% of proposed draws have been accepted in this batch (in master chain)
#
#   0.993595 seconds (18.38 M allocations: 625.520 MiB, 4.07% gc time, 21.00% compilation time)
# 28.807% of proposed draws have been accepted in this batch (in master chain)
#
# 29.199% of proposed draws have been accepted in this batch (in master chain)
#
# 29.246% of proposed draws have been accepted in this batch (in master chain)
#
# 28.911% of proposed draws have been accepted in this batch (in master chain)
#
# 28.925% of proposed draws have been accepted in this batch (in master chain)
#
# 29.392% of proposed draws have been accepted in this batch (in master chain)
#
# 29.034% of proposed draws have been accepted in this batch (in master chain)
#
# 29.134% of proposed draws have been accepted in this batch (in master chain)
#
# 29.141% of proposed draws have been accepted in this batch (in master chain)
#
# 29.01% of proposed draws have been accepted in this batch (in master chain)
#
#   0.944143 seconds (21.11 M allocations: 697.273 MiB, 5.24% gc time)
# 24.997% of proposed draws have been accepted in this batch (in master chain)
#
# 25.231% of proposed draws have been accepted in this batch (in master chain)
#
# 25.165% of proposed draws have been accepted in this batch (in master chain)
#
# 25.485% of proposed draws have been accepted in this batch (in master chain)
#
# 25.726% of proposed draws have been accepted in this batch (in master chain)
#
# 24.988% of proposed draws have been accepted in this batch (in master chain)
#
# 25.226% of proposed draws have been accepted in this batch (in master chain)
#
# 25.322% of proposed draws have been accepted in this batch (in master chain)
#
# 25.236% of proposed draws have been accepted in this batch (in master chain)
#
# 25.399% of proposed draws have been accepted in this batch (in master chain)
#
#   1.026590 seconds (18.73 M allocations: 624.485 MiB, 4.15% gc time)
# 24.274% of proposed draws have been accepted in this batch (in master chain)
#
# 24.026% of proposed draws have been accepted in this batch (in master chain)
#
# 24.471% of proposed draws have been accepted in this batch (in master chain)
#
# 24.718% of proposed draws have been accepted in this batch (in master chain)
#
# 24.483% of proposed draws have been accepted in this batch (in master chain)
#
# 23.625% of proposed draws have been accepted in this batch (in master chain)
#
# 23.523% of proposed draws have been accepted in this batch (in master chain)
#
# 24.411% of proposed draws have been accepted in this batch (in master chain)
#
# 24.076% of proposed draws have been accepted in this batch (in master chain)
#
# 23.292% of proposed draws have been accepted in this batch (in master chain)
#
#   1.478267 seconds (18.07 M allocations: 604.100 MiB, 2.71% gc time)
# 24.507% of proposed draws have been accepted in this batch (in master chain)
#
# 25.714% of proposed draws have been accepted in this batch (in master chain)
#
# 24.729% of proposed draws have been accepted in this batch (in master chain)
#
# 25.776% of proposed draws have been accepted in this batch (in master chain)
#
# 24.587% of proposed draws have been accepted in this batch (in master chain)
#
# 25.493% of proposed draws have been accepted in this batch (in master chain)
#
# 25.469% of proposed draws have been accepted in this batch (in master chain)
#
# 24.965% of proposed draws have been accepted in this batch (in master chain)
#
# 25.808% of proposed draws have been accepted in this batch (in master chain)
#
# 25.277% of proposed draws have been accepted in this batch (in master chain)
#
#   2.303537 seconds (19.26 M allocations: 640.723 MiB, 1.76% gc time)
# 26.191% of proposed draws have been accepted in this batch (in master chain)
#
# 25.837% of proposed draws have been accepted in this batch (in master chain)
#
# 26.741% of proposed draws have been accepted in this batch (in master chain)
#
# 26.466% of proposed draws have been accepted in this batch (in master chain)
#
# 25.04% of proposed draws have been accepted in this batch (in master chain)
#
# 25.046% of proposed draws have been accepted in this batch (in master chain)
#
# 24.792% of proposed draws have been accepted in this batch (in master chain)
#
# 27.306% of proposed draws have been accepted in this batch (in master chain)
#
# 26.294% of proposed draws have been accepted in this batch (in master chain)
#
# 27.097% of proposed draws have been accepted in this batch (in master chain)
#
#   3.827811 seconds (20.10 M allocations: 666.499 MiB, 1.16% gc time)
# 27.475% of proposed draws have been accepted in this batch (in master chain)
#
# 28.322% of proposed draws have been accepted in this batch (in master chain)
#
# 26.877% of proposed draws have been accepted in this batch (in master chain)
#
# 27.194% of proposed draws have been accepted in this batch (in master chain)
#
# 24.33% of proposed draws have been accepted in this batch (in master chain)
#
# 28.044% of proposed draws have been accepted in this batch (in master chain)
#
# 26.982% of proposed draws have been accepted in this batch (in master chain)
#
# 24.455% of proposed draws have been accepted in this batch (in master chain)
#
# 23.774% of proposed draws have been accepted in this batch (in master chain)
#
# 24.858% of proposed draws have been accepted in this batch (in master chain)
#
#   7.405422 seconds (20.33 M allocations: 673.297 MiB, 0.62% gc time)
# 28.663% of proposed draws have been accepted in this batch (in master chain)
#
# 27.707% of proposed draws have been accepted in this batch (in master chain)
#
# 28.544% of proposed draws have been accepted in this batch (in master chain)
#
# 24.522% of proposed draws have been accepted in this batch (in master chain)
#
# 29.687% of proposed draws have been accepted in this batch (in master chain)
#
# 24.794% of proposed draws have been accepted in this batch (in master chain)
#
# 26.839% of proposed draws have been accepted in this batch (in master chain)
#
# 27.692% of proposed draws have been accepted in this batch (in master chain)
#
# 29.566% of proposed draws have been accepted in this batch (in master chain)
#
# 25.817% of proposed draws have been accepted in this batch (in master chain)
#
#  16.523326 seconds (21.42 M allocations: 706.835 MiB, 0.25% gc time)
# 29.564% of proposed draws have been accepted in this batch (in master chain)
#
# 24.128% of proposed draws have been accepted in this batch (in master chain)
#
# 29.892% of proposed draws have been accepted in this batch (in master chain)
#
# 21.123% of proposed draws have been accepted in this batch (in master chain)
#
# 28.091% of proposed draws have been accepted in this batch (in master chain)
#
# 28.843% of proposed draws have been accepted in this batch (in master chain)
#
# 28.844% of proposed draws have been accepted in this batch (in master chain)
#
# 28.871% of proposed draws have been accepted in this batch (in master chain)
#
# 27.285% of proposed draws have been accepted in this batch (in master chain)
#
# 24.914% of proposed draws have been accepted in this batch (in master chain)
#
#  29.415169 seconds (21.21 M allocations: 700.376 MiB, 0.15% gc time)
# 28.227% of proposed draws have been accepted in this batch (in master chain)
#
# 24.9% of proposed draws have been accepted in this batch (in master chain)
#
# 26.151% of proposed draws have been accepted in this batch (in master chain)
#
# 28.088% of proposed draws have been accepted in this batch (in master chain)
#
# 28.744% of proposed draws have been accepted in this batch (in master chain)
#
# 29.517% of proposed draws have been accepted in this batch (in master chain)
#
# 27.135% of proposed draws have been accepted in this batch (in master chain)
#
# 27.038% of proposed draws have been accepted in this batch (in master chain)
#
# 29.378% of proposed draws have been accepted in this batch (in master chain)
#
# 24.779% of proposed draws have been accepted in this batch (in master chain)
#
#  46.948759 seconds (21.47 M allocations: 708.166 MiB, 0.09% gc time)
# 29.931% of proposed draws have been accepted in this batch (in master chain)
#
# 27.301% of proposed draws have been accepted in this batch (in master chain)
#
# 23.002% of proposed draws have been accepted in this batch (in master chain)
#
# 27.937% of proposed draws have been accepted in this batch (in master chain)
#
# 30.731% of proposed draws have been accepted in this batch (in master chain)
#
# 30.244% of proposed draws have been accepted in this batch (in master chain)
#
# 31.399% of proposed draws have been accepted in this batch (in master chain)
#
# 30.387% of proposed draws have been accepted in this batch (in master chain)
#
# 31.411% of proposed draws have been accepted in this batch (in master chain)
#
# 27.339% of proposed draws have been accepted in this batch (in master chain)
#
#  58.758259 seconds (22.94 M allocations: 757.875 MiB, 0.08% gc time)
# 30.2% of proposed draws have been accepted in this batch (in master chain)
#
# 26.499% of proposed draws have been accepted in this batch (in master chain)
#
# 27.212% of proposed draws have been accepted in this batch (in master chain)
#
# 31.999% of proposed draws have been accepted in this batch (in master chain)
#
# 31.112% of proposed draws have been accepted in this batch (in master chain)
#
# 28.474% of proposed draws have been accepted in this batch (in master chain)
#
# 27.178% of proposed draws have been accepted in this batch (in master chain)
#
# 25.551% of proposed draws have been accepted in this batch (in master chain)
#
# 26.803% of proposed draws have been accepted in this batch (in master chain)
#
# 30.306% of proposed draws have been accepted in this batch (in master chain)
#
#  96.769926 seconds (22.56 M allocations: 746.093 MiB, 0.07% gc time)

# %% [markdown]
# # OLD STUFF

# %% [markdown]
# ## Computing dihedral angles
#
# Let's compute the expectation value of the dihedral angle on the first node

# %%
function from_intertwiner_to_angle(i::Int64, j)
    return (i * (i + 1) - 2j * (j + 1)) / (2j * (j + 1))
end
# Out:
# from_intertwiner_to_angle (generic function with 1 method)

# %%
# not optimized

function angles_computation!(
    chains_to_assemble::Int64,
    angle_all_chains,
    angle_numerical_fluctuations,
    model::String,
    j::Float64,
    N,
    b,
    draws_folder::String,
)

    for chain_id = 1:chains_to_assemble

        @load "$(draws_folder)/ampls_chain=$(chain_id).jld2" ampls
        @load "$(draws_folder)/draws_chain=$(chain_id).jld2" draws
        number_of_elements_in_this_chain = size(ampls)[1]

        angle_this_chain = 0.0

        for i = 1:number_of_elements_in_this_chain
            angle_this_chain += from_intertwiner_to_angle(draws[i, 1] - 1, j) * draws[i, 6]
        end

        angle_this_chain /= (N - b)
        angle_all_chains[chain_id] = angle_this_chain

        # average_angle_first_node 
        angle_numerical_fluctuations[1] = mean(angle_all_chains[:])

        # std_dev_angle_first_node 
        angle_numerical_fluctuations[2] = std(angle_all_chains[:])

        # number of combined chains
        angle_numerical_fluctuations[3] = chains_to_assemble

    end

end
# Out:
# angles_computation! (generic function with 1 method)

# %%
using CSV, DataFrames

# %%
chains_to_assemble = nprocs()

N = 10^6
b = 0
σ = 0.9
draws_folder_base = "../data/MCMC/draws/N_$(N)_b_$(b)_$(σ)"
operator_folder_base = "../data/MCMC/operators/N_$(N)_b_$(b)_$(σ)"

for model in ["BF", "EPRL"]

    chain_id = myid()

    angle_fluctuations_table = DataFrame()

    # creating first column of angles numerical fluctuations dataframe 
    array = String[]
    push!(array, "avg. angles (first node)")
    push!(array, "std. angles (first node)")
    push!(array, "n. chains combined")

    angle_fluctuations_table = DataFrame(numerical_data = array)

    angle_all_chains = zeros(Float64, chains_to_assemble)
    angle_numerical_fluctuations = zeros(Float64, 3)

    for j = 0.5:0.5:6.0

        local draws_folder = "$(draws_folder_base)/$(model)/j_$(j)"

        column_name = "j=$(j)"

        # not optimized
        @time angles_computation!(
            chains_to_assemble,
            angle_all_chains,
            angle_numerical_fluctuations,
            model,
            j,
            N,
            b,
            draws_folder,
        )

        angle_numerical_fluctuations_dataframe =
            DataFrame(to_rename = angle_numerical_fluctuations)
        rename!(angle_numerical_fluctuations_dataframe, :to_rename => column_name)

        angle_fluctuations_table =
            hcat(angle_fluctuations_table, angle_numerical_fluctuations_dataframe)

    end

    local operator_folder = "$(operator_folder_base)/$(model)"
    mkpath(operator_folder)

    CSV.write(
        "$(operator_folder)/angles_numerical_fluctuations_table.csv",
        angle_fluctuations_table,
    )

end
# Out:
#   0.262609 seconds (10.40 M allocations: 278.984 MiB, 6.70% gc time)
#   0.278696 seconds (11.07 M allocations: 296.924 MiB, 7.15% gc time)
#   0.241452 seconds (9.18 M allocations: 246.362 MiB, 8.66% gc time)
#   0.217957 seconds (8.88 M allocations: 238.432 MiB, 4.49% gc time)
#   0.246234 seconds (9.50 M allocations: 254.841 MiB, 8.38% gc time)
#   0.242434 seconds (9.44 M allocations: 253.386 MiB, 7.68% gc time)
#   0.230148 seconds (9.28 M allocations: 249.154 MiB, 4.20% gc time)
#   0.247473 seconds (9.72 M allocations: 260.720 MiB, 9.01% gc time)
#   0.246514 seconds (9.61 M allocations: 257.920 MiB, 7.82% gc time)
#   0.241779 seconds (9.63 M allocations: 258.288 MiB, 4.93% gc time)
#   0.262808 seconds (9.86 M allocations: 264.595 MiB, 8.09% gc time)
#   0.261526 seconds (9.88 M allocations: 265.087 MiB, 8.55% gc time)
#   0.268311 seconds (10.43 M allocations: 279.750 MiB, 4.49% gc time)
#   0.286276 seconds (11.00 M allocations: 294.924 MiB, 8.95% gc time)
#   0.241538 seconds (9.32 M allocations: 250.202 MiB, 7.94% gc time)
#   0.224304 seconds (8.70 M allocations: 233.597 MiB, 8.61% gc time)
#   0.217811 seconds (8.93 M allocations: 239.669 MiB, 4.28% gc time)
#   0.241661 seconds (8.89 M allocations: 238.596 MiB, 9.59% gc time)
#   0.227923 seconds (8.95 M allocations: 240.191 MiB, 4.37% gc time)
#   0.239983 seconds (9.11 M allocations: 244.424 MiB, 8.04% gc time)
#   0.247170 seconds (9.25 M allocations: 248.314 MiB, 8.63% gc time)
#   0.235131 seconds (9.31 M allocations: 249.969 MiB, 4.45% gc time)
#   0.247865 seconds (9.48 M allocations: 254.345 MiB, 7.79% gc time)
#   0.250755 seconds (9.58 M allocations: 257.024 MiB, 8.32% gc time)
